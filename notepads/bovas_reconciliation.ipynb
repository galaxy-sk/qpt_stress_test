# %% [markdown]
# # Notebook to check direct db calls against Bovas's NAV report code

# %%
# %reload_ext autoreload
# %autoreload 
import sys, os
project_root_path = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root_path not in sys.path:
    sys.path.append(project_root_path)
print(project_root_path)

import datetime as dt
import numpy as np
import pandas as pd
import plotly.express as px

import pymd 
import nav.utils
from qpt_historic_pos.impl.utils.times import ChicagoTimeZone, UtcTimeZone
import qpt_stress_test.apps.generate_daily_summary as generate_daily_summary
import qpt_stress_test.services.positions as positions
import qpt_stress_test.core.config as config
import qpt_stress_test.core.qpt_config as qpt_config
import qpt_stress_test.db.tasks as db_tasks
import qpt_stress_test.db.repositories.drivers.pyodbc as pyodbc
import qpt_stress_test.db.repositories.drivers.sqlalchemy as sqlalchemy
import qpt_stress_test.db.repositories.qpt_pg as qpt_pg
import qpt_stress_test.db.repositories.qpt_mssql as qpt_mssql
import qpt_stress_test.db.repositories.databricks as db_trading
from qpt_stress_test.db.tasks import bfc_rds_sqlalchemy_engine_factory, sv_awoh_dw01_pyodbc_connection_factory,  gdt_cluster_databricks_connection_factory

from importlib import reload
reload(positions)
reload(config)
reload(qpt_config)
reload(db_tasks)

pymd.enable_logging()
# Out:
# c:\Users\skingham\Projects\galaxysk\qpt_stress_test

# %%
# Set dates, etc, for report generation
nav_date = dt.date(2023, 1, 4)
nav_00utc = dt.datetime.combine(nav_date + dt.timedelta(days=1), dt.time(hour=0, minute=0, second=0))
nav_ctz = UtcTimeZone.localize(dt.datetime.combine(nav_date + dt.timedelta(days=1), dt.time(hour=0, minute=0, second=0))).astimezone(ChicagoTimeZone)
derivs_utc_datetime = ChicagoTimeZone.localize(dt.datetime.combine(nav_date, dt.time(hour=16, minute=0, second=0))).astimezone(UtcTimeZone)

# %% [markdown]
# ## Get Summary Exchange Balances used in Bovas's NAV report

# %%
# %%capture
# This code is copied from the generate_daily_summary.py app 
mktdata_repo = qpt_mssql.MarketDataRepository(sql_query_driver=pyodbc.SqlQuery, db_connector_factory=sv_awoh_dw01_pyodbc_connection_factory)
operations_repo = qpt_mssql.OperationsRepository(sql_query_driver=pyodbc.SqlQuery, db_connector_factory=sv_awoh_dw01_pyodbc_connection_factory)
trading_repo = qpt_mssql.TradingRepository(sql_query_driver=pyodbc.SqlQuery, db_connector_factory=sv_awoh_dw01_pyodbc_connection_factory)
exchange_repo = qpt_mssql.RawDataRepository(sql_query_driver=pyodbc.SqlQuery, db_connector_factory=sv_awoh_dw01_pyodbc_connection_factory)

# Run Bowen's Net open positions report: should match email's from Bcai and Wenbo's emails:
net_open_position_report_df = generate_daily_summary.net_open_positions(derivs_utc_datetime, trading_repo)                                                             

# Run a facsimile of the Bovas NAV report: should  match Bovas NAV Summary_Exchange_Balances_00UTC worksheet
assets_df, loans_df, summary = generate_daily_summary.generate_daily_nav_00utc(nav_date)
summary_exchange_balances_df = generate_daily_summary.summary_exchange_balances_00utc(nav_date, assets_df, loans_df, summary)

## Reformat into format to combine nav & deriv positions
asset_loans_cash_df = generate_daily_summary.summary_asset_loans_cash(summary_exchange_balances_df)
asset_and_open_positions_df = pd.concat([net_open_position_report_df, asset_loans_cash_df], ignore_index=True)

# %%
# Take Bovas NAV report, un-mangle accounts
# ['Account','Balance','BalanceType','Currency','Source','Timestamp','Timestamp_Native','Notional','REFERENCE 1','REFERENCE 2','TYPE','Endpoint']
reported_eod_balances = summary_exchange_balances_df.copy()
reported_eod_balances.loc[(reported_eod_balances['Balance'] < 0) & (reported_eod_balances['BalanceType'] == ''), 'BalanceType'] = 'Margin Loan'
reported_eod_balances.loc[reported_eod_balances['Balance'] < 0, 'Account'] = reported_eod_balances.loc[reported_eod_balances['Balance'] < 0, 'Account'].replace(
    ['HUBI-M Margin Loan','HUB2-M Margin Loan','WOOX-1-M-E Margin Loan','FTXE-1-M-E Margin Loan', 'OKEX-2-M Margin Loan','OKEX-2-S3 Margin Loan','BINE-2-S1-M Margin Loan'],
    ['HUBI-M','HUB2-M','WOOX-1-M-E','FTXE-1-M-E', 'OKEX-2-M','OKEX-2-S3','BINE-2-S1-M'])

print(f"Bovas Net Asset Value w/o GD Capital: {summary_exchange_balances_df.Notional.sum():,.0f}; "
      f"Total NAV & Net Open Positions balance: {asset_and_open_positions_df.notional.sum():,.0f}")

usd_currencies = ('USD', 'USDT', 'USDC')
usd_like_balances = reported_eod_balances.loc[reported_eod_balances['Currency'].isin(usd_currencies)]
balances_ex_usd = reported_eod_balances.loc[~reported_eod_balances['Currency'].isin(usd_currencies)]
print(f"  {usd_currencies} balance: {usd_like_balances.Notional.sum():,.0f};  NAV excl USD like balances: {balances_ex_usd.Notional.sum():,.0f}")

#['utc_timestamp', 'exchange', 'account', 'instrument', 'position', 'notional', 'mark_price', 'unrealized_pnl', 'instrument_type', 'expiration_time', 'is_linear', 'underlying']
nav_by_account = asset_and_open_positions_df[['exchange', 'notional']].groupby(by=['exchange']).sum(numeric_only=True).reset_index()
display(nav_by_account)

nav_by_curency = reported_eod_balances[['Timestamp', 'Currency', 'Balance', 'Notional']].groupby(by=['Timestamp', 'Currency',]).sum(numeric_only=True).reset_index()
display(nav_by_curency)

# [Timestamp], [Account], [Currency], [Source], [BalanceType]	Notional Balance
nav_by_account_ccy = reported_eod_balances[['Timestamp', 'Endpoint', 'Currency', 'Source', 'BalanceType', 'Balance', 'Notional']].groupby(by=['Timestamp', 'Endpoint', 'Currency', 'Source', 'BalanceType']).sum(numeric_only=True).reset_index()
display(nav_by_account_ccy)
# Out:
# Bovas Net Asset Value w/o GD Capital: 32,047,940; Total NAV & Net Open Positions balance: 11,912,607
#   ('USD', 'USDT', 'USDC') balance: 21,297,699;  NAV excl USD like balances: 10,750,241
#        exchange        notional
# 0       BINANCE   14,559,017.85
# 1          BTFX          160.12
# 2          BTSE      157,674.21
# 3          BULL   48,367,717.43
# 4          CASH      699,614.89
# 5          DEFI    4,541,041.79
# 6          DYDX       -8,726.52
# 7          ED&F   76,598,881.22
# 8          FBLK   37,237,163.74
# 9        GALAXY -189,130,431.40
# 75   20230104                          OBALUSDC/BAL-30DEC22-7.6C
# 76   20230104                                                OMG
# 77   20230104                                                ONG
# 78   20230104                       OPERPUSDC/PERP-30DEC22-0.54C
# 79   20230104                  OSPELLUSDC/SPELL-30DEC22-0.00079C
# 80   20230104                  OWAVAXUSDC.E/WAVAX-06JAN23-12.25C
# 81   20230104                   OWAVAXUSDC.E/WAVAX-09DEC22-15.5C
# 82   20230104                  OWAVAXUSDC.E/WAVAX-16DEC22-15.25C
# 83   20230104                   OWAVAXUSDC.E/WAVAX-25NOV22-15.5C
# 84   20230104                  OWAVAXUSDC.E/WAVAX-30DEC22-13.25C
# 85   20230104                       OWETHUSDC/WETH-06JAN23-1300C
# 86   20230104                       OWETHUSDC/WETH-09DEC22-1450C
# 87   20230104                       OWETHUSDC/WETH-16DEC22-1450C
# 88   20230104                       OWETHUSDC/WETH-25NOV22-1400C
# 89   20230104                       OWETHUSDC/WETH-30DEC22-1350C
# 90   20230104                     OWETHUSDC/WSTETH-02DEC22-1350C
# 91   20230104                     OWETHUSDC/WSTETH-04NOV22-1700C
# 92   20230104                     OWETHUSDC/WSTETH-09SEP22-1900C
# 93   20230104                     OWETHUSDC/WSTETH-30DEC22-1350C
# 94   20230104                                                OXT
# 95   20230104                                               QTUM
# 96   20230104                                                REI
# 97   20230104                                               ROSE
# 98   20230104                                                SGB
# 99   20230104                                               SHFT
# 100  20230104                                               SHIB
# 101  20230104                                                SOL
# 102  20230104                                               SOLO
# 103  20230104                                              STORJ
# 104  20230104                                              SUSHI
# 105  20230104                                                TRX
# 106  20230104                                                TRY
# 107  20230104                                                 TT
# 108  20230104                                               TUSD
# 109  20230104                                                UNI
# 110  20230104                                                USD
# 111  20230104                                               USDC
# 112  20230104                                               USDP
# 113  20230104                                               USDT
# 114  20230104                                                UST
# 115  20230104                                                VET
# 116  20230104                                               VSYS
# 117  20230104                                              WAVAX
# 118  20230104                                               WETH
# 119  20230104                                                WOO
# 120  20230104                                                XEC
# 121  20230104                                                XLM
# 122  20230104                                                XRP
# 123  20230104                                                XTZ
# 124  20230104                                                YFI
# 125  20230104                                               YFII
# 126  20230104                                                ZEC
# 127  20230104                                                ZIL
#
#                Balance       Notional
# 0           180,000.00           0.00
# 1             7,000.00           0.00
# 2             7,000.00           0.00
# 3             7,000.00           0.00
# 4                 8.00           0.00
# 5               377.10           0.10
# 6               192.00      10,903.36
# 7           -16,322.80      -4,369.25
# 8             3,628.71         678.90
# 9                 0.53           0.01
# 10                0.38           3.87
# 11              394.10       4,759.78
# 12          -11,965.87      -2,159.49
# 13              866.02      87,885.92
# 14                0.00           0.00
# 15              115.30           6.15
# 16            2,599.86     673,675.85
# 17               14.75           2.52
# 18               25.00           0.00
# 19                0.59          25.21
# 20               36.81     620,731.27
# 21                0.34           0.00
# 22    1,367,501,156.88         863.92
# 23       14,874,781.83  14,879,969.98
# 24                1.79           0.00
# 25              221.39       7,357.56
# 26                0.31           0.02
# 27           14,183.71       7,866.83
# 28              279.37         892.56
# 29          138,708.93     138,718.34
# 30               -0.10          -4.69
# 31            3,391.93         248.41
# 32                0.00           0.00
# 33             -723.70      -3,350.86
# 34              -94.34         -23.60
# 35          146,647.53     133,041.70
# 36             -743.42     -14,263.96
# 37            4,553.92   5,722,116.84
# 38            9,823.84       3,421.32
# 39            4,732.54      15,934.01
# 40          798,437.91     846,627.63
# 41      -14,656,794.44 -15,527,831.81
# 42                1.19           3.98
# 43              -71.36         -15.60
# 44                3.22           3.23
# 45              495.86       2,499.45
# 46               54.78         111.58
# 47                0.01           0.01
# 48           -6,514.34        -398.03
# 49            1,700.74          65.49
# 50            5,337.70           1.08
# 51            1,655.06       8,636.87
# 52          480,000.00           0.00
# 53               14.79           0.11
# 54                0.82           0.01
# 55                9.11           0.18
# 56                0.01           0.23
# 57                0.24           0.00
# 58                0.00           0.00
# 59           74,740.60     433,796.80
# 60                4.33           0.00
# 61            2,693.61     203,189.69
# 62                0.66           0.00
# 63            8,861.67       2,853.76
# 64           -9,661.25      -7,790.56
# 65          497,605.77     496,652.95
# 66               -0.07         -35.38
# 67                0.89           5.87
# 68               40.70           0.01
# 69    3,049,025,070.20       1,296.12
# 70                0.00           0.00
# 71           34,311.93           0.00
# 72           32,302.94           0.00
# 73           33,793.38           0.00
# 74           33,991.37           0.00
# 75          196,525.25           0.00
# 76           24,403.36      26,364.12
# 77                0.35           0.08
# 78          201,000.92           0.00
# 79      100,050,250.67           0.00
# 80           19,597.43           0.00
# 81           29,214.15           0.00
# 82           20,213.41           0.00
# 83           31,925.00           0.00
# 84           17,599.94           0.00
# 85            3,032.00           0.00
# 86            2,698.00           0.00
# 87            2,891.00           0.00
# 88            2,904.00           0.00
# 89            3,047.00           0.00
# 90            9,472.13           0.00
# 91            5,625.03           0.00
# 92            5,968.00           0.00
# 93            4,006.00           0.00
# 94           14,449.69       1,002.27
# 95                0.00           0.01
# 96                0.03           0.00
# 97                0.00           0.00
# 98        1,236,499.88      24,748.77
# 99        3,449,324.22      27,856.48
# 100 174,013,333,266.89   1,457,473.12
# 101             890.80      11,967.94
# 102          38,753.77       6,329.60
# 103              29.76           7.71
# 104             -16.80         -16.65
# 105              45.22           2.48
# 106               0.11           0.00
# 107               0.06           0.00
# 108              20.00          20.01
# 109          -1,886.83     -10,426.51
# 110      41,176,782.38  41,176,782.38
# 111     -57,893,891.15 -57,894,099.44
# 112               0.35           0.35
# 113      38,024,040.88  38,015,016.12
# 114              29.99           0.00
# 115             -74.04          -1.23
# 116               0.21           0.00
# 117              76.89         926.61
# 118             128.59     161,549.36
# 119       1,644,286.05     215,821.18
# 120      97,856,395.37       2,290.21
# 121             397.62          29.36
# 122         123,728.98      43,032.25
# 123              -7.40          -5.67
# 124               4.19      22,549.52
# 125               0.02          18.79
# 126               0.00           0.01
# 127         834,815.06      14,094.29
#     Timestamp     Endpoint                                           Currency  \
# 0    20230104         BINE                                               AAVE
# 1    20230104         BINE                                               AAVE
# 2    20230104         BINE                                                ADA
# 3    20230104         BINE                                                ADA
# 88   20230104         BTSE                                                ETH
# 89   20230104         BTSE                                                SGB
# 90   20230104         BTSE                                                USD
# 91   20230104         BTSE                                                XRP
# 92   20230104         BULL                                                BTC
# 93   20230104         BULL                                                BTC
# 94   20230104         BULL                                                BTC
# 95   20230104         BULL                                                EOS
# 96   20230104         BULL                                                EOS
# 97   20230104         BULL                                                ETH
# 98   20230104         BULL                                                ETH
# 99   20230104         BULL                                                ETH
# 100  20230104         BULL                                               LINK
# 101  20230104         BULL                                                LTC
# 102  20230104         BULL                                                USD
# 103  20230104         BULL                                                USD
# 104  20230104         BULL                                                USD
# 105  20230104         BULL                                               USDC
# 106  20230104         CASH                                                USD
# 107  20230104         DEFI       $ PLEASE VISIT ACADY.SITE TO RECEIVE REWARD.
# 108  20230104         DEFI            $ USDCBONUS.COM <- VISIT TO CLAIM BONUS
# 109  20230104         DEFI             $ USDCGIFT.COM <- VISIT TO CLAIM BONUS
# 110  20230104         DEFI              $ USDCXMAS.COM <- VISIT TO CLAIM GIFT
# 111  20230104         DEFI                  927$ VISIT AUSDBONUS.COM TO CLAIM
# 112  20230104         DEFI                                               AAVE
# 113  20230104         DEFI                                               AVAX
# 114  20230104         DEFI  BONUS. VISIT HTTPS://BITBONUS.TECH TO CLAIM RE...
# 115  20230104         DEFI                                                CRV
# 116  20230104         DEFI                                                CRV
# 117  20230104         DEFI                                                CVX
# 118  20230104         DEFI                                                DAI
# 119  20230104         DEFI                                                ETH
# 120  20230104         DEFI                                                ETH
# 121  20230104         DEFI                                                FXS
# 122  20230104         DEFI                                                FXS
# 123  20230104         DEFI  INVITATION TOKEN. PLEASE VISIT HTTPS://AAKER.S...
# 124  20230104         DEFI                                                MIM
# 125  20230104         DEFI                       OAAVEUSDC/AAVE-02DEC22-67.5C
# 126  20230104         DEFI                       OAAVEUSDC/AAVE-06JAN23-62.5C
# 127  20230104         DEFI                       OAAVEUSDC/AAVE-16DEC22-72.5C
# 128  20230104         DEFI                       OAAVEUSDC/AAVE-25NOV22-72.5C
# 129  20230104         DEFI                          OBALUSDC/BAL-30DEC22-7.6C
# 130  20230104         DEFI                       OPERPUSDC/PERP-30DEC22-0.54C
# 131  20230104         DEFI                  OSPELLUSDC/SPELL-30DEC22-0.00079C
# 132  20230104         DEFI                  OWAVAXUSDC.E/WAVAX-06JAN23-12.25C
# 133  20230104         DEFI                   OWAVAXUSDC.E/WAVAX-09DEC22-15.5C
# 134  20230104         DEFI                  OWAVAXUSDC.E/WAVAX-16DEC22-15.25C
# 135  20230104         DEFI                   OWAVAXUSDC.E/WAVAX-25NOV22-15.5C
# 136  20230104         DEFI                  OWAVAXUSDC.E/WAVAX-30DEC22-13.25C
# 137  20230104         DEFI                       OWETHUSDC/WETH-06JAN23-1300C
# 138  20230104         DEFI                       OWETHUSDC/WETH-09DEC22-1450C
# 139  20230104         DEFI                       OWETHUSDC/WETH-16DEC22-1450C
# 140  20230104         DEFI                       OWETHUSDC/WETH-25NOV22-1400C
# 374  20230104         KRKE                                                SGB
# 375  20230104         KRKE                                                USD
# 376  20230104         KRKE                                               USDT
# 377  20230104         KRKE                                                XLM
# 378  20230104         KRKE                                                XRP
# 379  20230104         LMAC                                                ETH
# 380  20230104         LMAC                                                USD
# 381  20230104         LMAX                                                USD
# 382  20230104         OKEX                                                BSV
# 383  20230104         OKEX                                                BTC
# 384  20230104         OKEX                                                BTC
# 385  20230104         OKEX                                                BTC
# 386  20230104         OKEX                                                BTC
# 387  20230104         OKEX                                                DOT
# 388  20230104         OKEX                                                EOS
# 389  20230104         OKEX                                                ETH
# 390  20230104         OKEX                                                ETH
# 391  20230104         OKEX                                                ETH
# 392  20230104         OKEX                                               ETHW
# 393  20230104         OKEX                                                FIL
# 394  20230104         OKEX                                                LTC
# 395  20230104         OKEX                                                LTC
# 396  20230104         OKEX                                                OXT
# 397  20230104         OKEX                                               SHIB
# 398  20230104         OKEX                                               SHIB
# 399  20230104         OKEX                                               USDC
# 400  20230104         OKEX                                               USDT
# 401  20230104         OKEX                                               USDT
# 402  20230104         OKEX                                               USDT
# 403  20230104         OKEX                                               USDT
# 404  20230104         OKEX                                               USDT
# 405  20230104         OKEX                                                XEC
# 406  20230104         OKEX                                                XRP
# 407  20230104         OKEX                                                XRP
# ...
# 335                 hubi.account_balance                     1,884,988.30
# 336         hubi_1_m_p.swap_account_info       Balance          71,073.21
# 337                 hubi.account_balance                             0.14
# 338                 hubi.account_balance                        38,753.77
# 339                 hubi.account_balance                            29.76
# 340           fub2.contract_account_info       Balance               0.00
# 341           fubi.contract_account_info       Balance               0.96
# 342                 hubi.account_balance                            44.27
# 343         hubi_1_m_p.swap_account_info       Balance               0.00
# 344                 hubi.account_balance                             0.06
# 345                 hubi.account_balance                            20.00
# 346                 hubi.account_balance                             0.00
# 347                 hubi.account_balance                             0.00
# 348                 hubi.account_balance                             0.35
# 349                                    0       Balance         999,301.17
# 350                                    0    Unrealized             472.92
# 351                 hub2.account_balance                             3.26
# 352                 hubi.account_balance                     2,955,527.82
# 353                 hubi.account_balance                            25.96
# 354                 hubi.account_balance                             0.21
# 355                 hubi.account_balance                    97,856,389.90
# 356                 hubi.account_balance                             0.56
# 357           fub2.contract_account_info       Balance               0.00
# 358           fubi.contract_account_info       Balance               0.54
# 359                 hub2.account_balance                             0.00
# 360                 hubi.account_balance                           300.60
# 361         hubi_1_m_p.swap_account_info       Balance               0.00
# 362                 hubi.account_balance                             3.93
# 363                 hubi.account_balance                             0.01
# 364         hubi_1_m_p.swap_account_info       Balance               0.00
# 365                 hubi.account_balance                             0.00
# 366                 hubi.account_balance                    18,892,200.03
# 367              crypto.snapshotbalances                             0.33
# 368              crypto.snapshotbalances                             1.77
# 369              crypto.snapshotbalances                             0.02
# 370              crypto.snapshotbalances                             9.95
# 371              crypto.snapshotbalances                             3.40
# 372              crypto.snapshotbalances                             9.14
# 373              crypto.snapshotbalances                       734,064.56
# 374              crypto.snapshotbalances                             0.11
# 375              crypto.snapshotbalances                       125,911.49
# 376              crypto.snapshotbalances                             0.01
# 377              crypto.snapshotbalances                             0.01
# 378              crypto.snapshotbalances                             0.72
# 379              crypto.snapshotbalances                             0.00
# 380              crypto.snapshotbalances                             0.00
# 381              crypto.snapshotbalances                        10,140.41
# 382      okex_2_u1.funding_asset_balance       Balance               0.00
# 383                                    0       Balance               1.39
# 384            okex_2_s1.account_balance       Balance               0.00
# 385            okex_2_u1.account_balance       Balance             432.92
# 386            okex_2_u1.account_balance    Unrealized              -0.09
# 387      okex_2_u1.funding_asset_balance       Balance               0.00
# 388            okex_2_u1.account_balance       Balance         -18,513.53
# 389            okex_2_s1.account_balance       Balance               0.00
# 390            okex_2_u1.account_balance       Balance           8,475.35
# 391            okex_2_u1.account_balance    Unrealized             -93.38
# 392      okex_2_u1.funding_asset_balance       Balance               0.00
# 393            okex_2_u1.account_balance       Balance              -0.04
# 394            okex_2_u1.account_balance       Balance            -387.69
# 395      okex_2_u1.funding_asset_balance       Balance               0.00
# 396            okex_2_u1.account_balance       Balance         625,669.19
# 397            okex_2_u1.account_balance       Balance -10,044,814,926.94
# 398      okex_2_u1.funding_asset_balance       Balance               0.00
# 399      okex_2_u1.funding_asset_balance       Balance               0.00
# 400                                    0       Balance          14,208.97
# 401                                    0    Unrealized         -19,953.85
# 402            okex_2_s2.account_balance       Balance               0.01
# 403            okex_2_u1.account_balance       Balance       3,737,040.29
# 404            okex_2_u1.account_balance    Unrealized         202,210.77
# 405      okex_2_u1.funding_asset_balance       Balance               5.47
# 406            okex_2_s1.account_balance       Balance               0.45
# 407            okex_2_u1.account_balance       Balance           6,696.57
# 408      okex_2_u1.funding_asset_balance       Balance               0.00
# 409            okex_2_u1.account_balance       Balance       1,942,615.03
# 410                                    0   Margin Loan      -2,600,208.00
# 411                                    0   Margin Loan      -1,000,000.00
# 412                                    0                             0.00
# 413                                    0                             0.01
# 414                                    0                             0.01
# 415                                    0                             0.11
# 416                                    0                             0.01
# 417                                    0                             0.00
# 418                                    0                             0.00
# 419                     crypto.transfers   Margin Loan            -201.17
# 420                                    0                     3,449,324.22
# 421                                                             79,941.92
# 422                                    0                            31.26
# 423                                    0                         1,058.63
# 424                                    0                       994,319.93
# 425                                    0                     1,644,286.05
#
#           Notional
# 0        32,334.51
# 1       -51,108.75
# 2        75,133.84
# 3      -120,454.85
# 4        39,880.85
# 5       -45,800.26
# 6             0.04
# 7        38,890.26
# 8       -72,465.68
# 9        14,170.15
# 10      -36,094.19
# 11       32,098.62
# 12       -9,133.45
# 13       14,014.39
# 14      646,979.19
# 15       12,682.22
# 16       83,532.99
# 17   14,184,628.29
# 18      -40,288.04
# 19    6,578,538.04
# 20           43.18
# 21    3,876,085.34
# 22   11,003,841.46
# 23          681.10
# 24     -159,522.08
# 25            0.01
# 26       41,120.04
# 27      -45,799.44
# 28       35,819.53
# 29      -80,560.64
# 30       18,524.26
# 31      -46,301.91
# 32       10,995.08
# 33      -15,011.24
# 34       78,027.45
# 35      -70,416.13
# 36            3.02
# 37       37,933.16
# 38    8,544,959.10
# 39      -85,178.81
# 40    4,936,615.80
# 41      846,627.62
# 42            0.67
# 43       58,410.68
# 44      -65,597.47
# 45       10,940.39
# 46      -14,664.13
# 47       18,153.09
# 48      -24,212.87
# 49       41,690.75
# 50     -122,796.14
# 51       64,524.65
# 52     -121,357.77
# 53       15,852.07
# 54      -28,983.05
# 55       32,528.05
# 56      -80,637.22
# 57        6,778.77
# 58       -7,263.45
# 59       26,182.07
# 60       24,255.56
# 61       25,597.57
# 62      -50,253.84
# 63       78,883.52
# 64     -114,198.46
# 65       20,918.33
# 66      -42,804.11
# 67       22,723.78
# 68      -66,311.39
# 69      724,104.60
# 70        3,163.16
# 71      636,770.52
# 72    1,043,656.90
# 73   15,105,487.74
# 74     -142,706.27
# 75           -1.66
# 76       65,732.12
# 77      -73,835.58
# 78       48,421.76
# 79      -52,278.01
# 80          281.82
# 81          134.90
# 82           25.13
# 83            0.07
# 84            0.03
# 85            0.00
# 86           22.26
# 87          975.73
# 88          924.07
# 89          445.89
# 90      114,736.84
# 91       40,569.42
# 92  -56,491,848.17
# 93   41,178,872.26
# 94    1,138,937.87
# 95   -3,947,156.88
# 96    4,009,304.21
# 97   -8,167,416.58
# 98   16,253,322.84
# 99    1,352,579.21
# 100     561,802.02
# 101     579,714.57
# 102  36,364,893.96
# 103   3,271,045.63
# 104  12,263,665.98
# 105           0.50
# 106     699,614.89
# 107           0.00
# 108           0.00
# 109           0.00
# 110           0.00
# 111           0.00
# 112      11,262.13
# 113         833.43
# 114           0.00
# 115       3,079.62
# 116       4,787.20
# 117         892.56
# 118     138,718.34
# 119   1,253,036.52
# 120      33,791.68
# 121       1,003.11
# 122       1,496.33
# 123           0.00
# 124     496,652.95
# 125           0.00
# 126           0.00
# 127           0.00
# 128           0.00
# 129           0.00
# 130           0.00
# 131           0.00
# 132           0.00
# 133           0.00
# 134           0.00
# 135           0.00
# 136           0.00
# 137           0.00
# 138           0.00
# 139           0.00
# 140           0.00
# 141           0.00
# 142           0.00
# 143           0.00
# 144           0.00
# 145           0.00
# 146  12,160,425.85
# 147      74,511.23
# 148 -10,018,285.23
# 149     216,360.08
# 150         926.61
# 151     161,549.36
# 152      19,411.58
# 153  31,046,831.22
# 154       1,373.53
# 155         800.15
# 156          50.07
# 157       1,268.74
# 158       1,717.45
# 159         546.31
# 160           0.05
# 161   2,060,145.24
# 162          29.71
# 163          94.76
# 164       1,047.36
# 165         388.00
# 166         239.75
# 167      26,632.67
# 168          11.03
# 169   2,744,327.07
# 170       4,269.85
# 171     258,254.74
# 172         611.44
# 173           2.55
# 174         270.69
# 175       1,311.96
# 176           0.22
# 177       7,812.61
# 178      16,055.70
# 179       1,493.11
# 180         449.31
# 181         182.05
# 182          65.52
# 183         258.10
# 184         467.08
# 185           5.40
# 186  20,557,877.75
# 187  11,547,493.09
# 188         749.22
# 189          98.63
# 190          12.61
# 191         750.24
# 192      17,036.25
# 193      40,151.62
# 194       6,548.24
# 195      36,232.84
# 196      18,047.09
# 197     571,043.36
# 198 -22,597,023.36
# 199     166,168.84
# 200       4,579.94
# 201      43,942.17
# 202      23,150.96
# 203       3,752.81
# 204      27,216.63
# 205   1,880,315.03
# 206 -32,487,495.10
# 207 -15,891,433.71
# 208       6,559.75
# 209       3,055.03
# 210       4,813.31
# 211      40,628.22
# 212      37,716.95
# 213      14,491.52
# 214      40,318.61
# 215       5,549.03
# 216   1,566,244.77
# 217      47,022.90
# 218      21,402.06
# 219      33,155.69
# 220 -42,800,000.00
# 221 -89,706,322.75
# 222   9,997,626.57
# 223       7,383.56
# 224       3,834.95
# 225      21,517.46
# 226    -337,662.64
# 227           1.68
# 228         320.39
# 229           3.36
# 230           1.25
# 231           0.00
# 232           0.00
# 233           0.00
# 234      20,235.48
# 235          27.16
# 236          59.38
# 237           0.10
# 238           5.69
# 239           0.00
# 240           0.00
# 241           0.00
# 242           0.00
# 243           0.00
# 244           0.00
# 245           0.01
# 246           0.45
# 247           0.19
# 248           0.00
# 249    -507,413.69
# 250           0.00
# 251          73.97
# 252           0.00
# 253         468.90
# 254           0.05
# 255           0.00
# 256           6.15
# 257           2.52
# 258          20.34
# 259           4.85
# 260           0.00
# 261           0.01
# 262           0.00
# 263           0.00
# 264           0.09
# 265   4,911,850.36
# 266   1,762,078.15
# 267         198.08
# 268           0.00
# 269         863.92
# 270           0.00
# 271           0.02
# 272           0.00
# 273           0.00
# 274    -185,207.64
# 275           4.53
# 276     186,090.94
# 277           0.02
# 278           0.00
# 279    -145,155.35
# 280           0.00
# 281           0.03
# 282           0.00
# 283     171,375.90
# 284  -2,072,183.91
# 285           0.00
# 286          13.57
# 287           0.00
# 288     177,575.37
# 289           1.94
# 290  -5,780,022.34
# 291           0.00
# 292           1.20
# 293           0.00
# 294   3,336,893.89
# 295   1,886,039.50
# 296        -591.62
# 297       3,421.32
# 298      11,652.63
# 299     105,347.16
# 300           3.44
# 301           0.69
# 302         111.58
# 303           0.00
# 304           1.08
# 305       8,636.87
# 306           0.11
# 307           0.01
# 308           0.18
# 309           0.00
# 310           0.00
# 311           0.00
# 312     -98,668.54
# 313           0.36
# 314           0.00
# 315       3,327.51
# 316           0.01
# 317           0.00
# 318    -890,120.11
# 319           0.00
# 320         539.84
# 321           0.00
# 322     544,670.89
# 323           0.19
# 324           0.00
# 325           0.11
# 326           5.87
# 327           0.01
# 328       1,296.12
# 329           0.00
# 330           0.08
# 331      57,175.04
# 332           0.01
# 333           0.00
# 334      24,302.88
# 335          15.79
# 336           0.60
# 337           1.90
# 338       6,329.60
# 339           7.71
# 340           0.00
# 341           0.05
# 342           2.42
# 343           0.00
# 344           0.00
# 345          20.01
# 346           0.00
# 347           0.00
# 348           0.35
# 349     999,063.99
# 350         472.81
# 351           3.26
# 352   2,954,826.34
# 353           0.43
# 354           0.00
# 355       2,290.21
# 356           0.04
# 357           0.00
# 358           0.19
# 359           0.00
# 360         104.55
# 361           0.00
# 362           3.01
# 363          15.88
# 364           2.90
# 365           0.01
# 366     318,959.50
# 367           3.38
# 368         179.58
# 369         317.83
# 370           9.03
# 371          11.46
# 372         689.63
# 373      50,916.84
# 374           0.00
# 375     125,911.49
# 376           0.01
# 377           0.00
# 378           0.25
# 379           0.63
# 380           0.00
# 381      10,140.41
# 382           0.00
# 383      23,378.73
# 384           0.00
# 385   7,300,367.15
# 386      -1,478.97
# 387           0.00
# 388     -16,795.87
# 389           0.01
# 390  10,649,501.77
# 391    -117,330.45
# 392           0.00
# 393          -0.12
# 394     -29,244.85
# 395           0.00
# 396      43,398.22
# 397     -84,131.76
# 398           0.00
# 399           0.00
# 400      14,205.60
# 401     -19,949.11
# 402           0.01
# 403   3,736,153.33
# 404     202,162.78
# 405           0.00
# 406           0.16
# 407       2,329.03
# 408           0.00
# 409      32,797.43
# 410    -180,357.94
# 411  -1,000,003.60
# 412           0.90
# 413           0.01
# 414           0.01
# 415           0.00
# 416           0.01
# 417           0.00
# 418           0.00
# 419         -69.97
# 420      27,856.48
# 421      79,941.92
# 422     527,088.66
# 423   1,330,198.01
# 424     994,083.93
# 425     215,821.18

# %% [markdown]
# ## Reconcile Bovas totals
#
# Let's just take the queries that Bovas uses to get crypto exchange asset & loan entries and look at all entries for 'Operations.balances.EndOfDay_00UTC'.  What's missing?

# %%
# Bovas config
bovas_asset_account_name_replacement = (
    ['OKEX-2-W1', 'OKEX-2-U1', 'FBLK-AUDIT-BINE', 'FBLK-AUDIT-HUBI', 'FBLK-AUDIT-OKEX', 'FBLK-Default', 'FBLK-GOTC-GACM', 'FBLK-LEND-BTGO', 'FBLK-LEND-DRAW', 
     'FBLK-LEND-OXTF', 'FBLK-LEND-XRPF', 'FBLK-LMAC-M', 'FBLK-Network Deposits', 'FBLK-PITX-E', 'FBLK-LEND-CELS', 'FBLK-LEND-GADI', 'FBLK-LEND-NICO', 
     'FBLK-LEND-GENX','FBLK-BINE-MX-S1','FBLK-DEFI-AAVE','FBLK-GOTC-BIGO','FBLK-DYDX-1-M-P','FBLK-WOOX-1-M-E','FBLK-LEND-GACM'], 
    ['OKEX-2-M-W', 'OKEX-2-M', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK','FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 'FBLK', 
     'FBLK', 'FBLK', 'FBLK', 'FBLK'])

bovas_loan_account_name_replacement = (
    ['HUBI-M','HUB2-M','WOOX-1-M-E','FTXE-1-M-E','OKEX-2-U1','OKEX-2-S3','BINE-2-S1-M'],
    ['HUBI-M Margin Loan','HUB2-M Margin Loan','WOOX-1-M-E Margin Loan','FTXE-1-M-E Margin Loan', 
     'OKEX-2-M Margin Loan','OKEX-2-S3 Margin Loan','BINE-2-S1-M Margin Loan'])

bovas_currency_replacement = (
    ['USDT_ERC20','SRM_LOCKED','BTCUSD','ETHUSD','EOSUSD','LINKUSD','LTCUSD','ATOM.S','DOT.S','KSM.S','FTM_FANTOM','AUSDC_ETH',
     'CVXCRV-F','VARIABLEDEBTCRV','BNB_BSC','ZIL_BSC','EUROC_ETH_F5NG','USDTEST','FRXETH','AAVAUSDC','VARIABLEDEBTAVAUSDT',
     'VARIABLEDEBTUSDT','AURAB-STETH-STABLE-VAULT'],
    ['USDT','SRM','BTC','ETH','EOS','LINK','LTC','ATOM','DOT','KSM','FTM','AUSDC','CVX','CRV','BNB','ZIL','EUROC','USD','ETH',
    'AUSDC','USDT','USDT','ETH'])

# %%
# %%capture
# Do a direct call against the database:
#
marks_df = mktdata_repo.get_coinmarketcap_close_marks(nav_date).as_dataframe()
# Add in EUR, GBP, etc missing from coinbase
marks2_df = mktdata_repo.get_trading_close_marks(nav_date).as_dataframe()
marks_df = pd.concat([marks_df, marks2_df.loc[~marks2_df['Currency'].isin(marks_df.Currency)]], ignore_index=True)
# Drop duplicates
marks_df.Currency = marks_df.Currency.apply(str.upper)
marks_df.drop(marks_df[marks_df.Currency.duplicated(keep="first")].index, axis=0, inplace=True)
# adding coins which are having a different name but essentially same as an existing coin
marks_df.set_index('Currency', inplace=True)
marks_df.loc['AUSDC'] = marks_df.loc['USDC'].values
marks_df.loc['AWETH'] = marks_df.loc['WETH'].values
marks_df.loc['FRXETH'] = marks_df.loc['ETH'].values

# %%
# %%capture
bovas_loans_qry = """
select a.Account, a.Balance, a.BalanceType, UPPER(a.Currency) as Currency, 
    Isnull(b.TableName, '') as Source, FORMAT(a.Date_UTC,'yyyyMMdd') as Timestamp, a.AsOf_UTC as Timestamp_Native
from Operations.balances.EndOfDay_00UTC A 
    LEFT JOIN Operations.balances.sources B on a.Account = b.Account 
where balance != 0 
    and a.Date_UTC = '{date:%Y-%m-%d}' 
    and Currency not like '%SWAP%' 
    and a.Account in {accounts} 
    and balancetype != 'unrealized' 
order by Account
""".format(date=nav_date, accounts=tuple(qpt_config.loan_accounts))
bovas_loans_df = trading_repo.adhoc_query(bovas_loans_qry).as_dataframe()

bovas_assets_qry = """
select a.Account, a.Balance, a.BalanceType, UPPER(a.Currency) as Currency,  
    Isnull(b.TableName, '') as Source, FORMAT(a.Date_UTC,'yyyyMMdd') as Timestamp, a.AsOf_UTC as Timestamp_Native 
from Operations.balances.EndOfDay_00UTC A 
    LEFT JOIN Operations.balances.sources B on a.Account = b.Account 
where balance != 0 and a.Date_UTC = '{date:%Y-%m-%d}' 
    and Currency not like '%SWAP%' 
    and a.Account in {accounts} 
    and Seconds_from_00UTC <= 79259
order by Account
""".format(date=nav_date, accounts=tuple(qpt_config.exchange_balance_accounts))
bovas_assets_df = trading_repo.adhoc_query(bovas_assets_qry).as_dataframe()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File c:\Users\skingham\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:2019, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2018 try:
# -> 2019     cur.execute(*args, **kwargs)
#    2020     return cur
#
# Error: ('01000', '[01000] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionWrite (send()). (10054) (SQLExecDirectW); [01000] [Microsoft][ODBC SQL Server Driver][DBNETLIB]General network error. Check your network documentation. (11)')
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In [40], line 13
#       1 bovas_loans_qry = """
#       2 select a.Account, a.Balance, a.BalanceType, UPPER(a.Currency) as Currency,
#       3     Isnull(b.TableName, '') as Source, FORMAT(a.Date_UTC,'yyyyMMdd') as Timestamp, a.AsOf_UTC as Timestamp_Native
#    (...)
#      11 order by Account
#      12 """.format(date=nav_date, accounts=tuple(qpt_config.loan_accounts))
# ---> 13 bovas_loans_df = trading_repo.adhoc_query(bovas_loans_qry).as_dataframe()
#      15 bovas_assets_qry = """
#      16 select a.Account, a.Balance, a.BalanceType, UPPER(a.Currency) as Currency,
#      17     Isnull(b.TableName, '') as Source, FORMAT(a.Date_UTC,'yyyyMMdd') as Timestamp, a.AsOf_UTC as Timestamp_Native
#    (...)
#      24 order by Account
#      25 """.format(date=nav_date, accounts=tuple(qpt_config.exchange_balance_accounts))
#      26 bovas_assets_df = trading_repo.adhoc_query(bovas_assets_qry).as_dataframe()
#
# File c:\Users\skingham\Projects\galaxysk\qpt_stress_test\qpt_stress_test\db\repositories\drivers\pyodbc.py:47, in SqlQuery.as_dataframe(self)
#      46 def as_dataframe(self):
# ---> 47     df = pd.read_sql(self._query, con=self._pyodbc_conn_factory())
#      48     return df
#
# File c:\Users\skingham\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:565, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     562 pandas_sql = pandasSQL_builder(con)
#     564 if isinstance(pandas_sql, SQLiteDatabase):
# --> 565     return pandas_sql.read_query(
#     566         sql,
#     567         index_col=index_col,
#     568         params=params,
#     569         coerce_float=coerce_float,
#     570         parse_dates=parse_dates,
#     571         chunksize=chunksize,
#     572     )
#     574 try:
#     575     _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\skingham\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:2079, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2067 def read_query(
#    2068     self,
#    2069     sql,
#    (...)
#    2075     dtype: DtypeArg | None = None,
#    2076 ) -> DataFrame | Iterator[DataFrame]:
#    2078     args = _convert_params(sql, params)
# -> 2079     cursor = self.execute(*args)
#    2080     columns = [col_desc[0] for col_desc in cursor.description]
#    2082     if chunksize is not None:
#
# File c:\Users\skingham\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:2031, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2028     raise ex from inner_exc
#    2030 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2031 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# select a.Account, a.Balance, a.BalanceType, UPPER(a.Currency) as Currency,
#     Isnull(b.TableName, '') as Source, FORMAT(a.Date_UTC,'yyyyMMdd') as Timestamp, a.AsOf_UTC as Timestamp_Native
# from Operations.balances.EndOfDay_00UTC A
#     LEFT JOIN Operations.balances.sources B on a.Account = b.Account
# where balance != 0
#     and a.Date_UTC = '2023-01-04'
#     and Currency not like '%SWAP%'
#     and a.Account in ('LEND-GACM', 'LEND-HUBI', 'LEND-LMAC', 'LEND-PITX', 'LEND-XRPF', 'LEND-OKEX', 'HUBI-3-S3-M Loan', 'HUBI-M', 'HUB2-M', 'LEND-OXTF', 'WOOX-1-M-E', 'FTXE-1-M-E', 'OKEX-2-U1', 'LEND-HUBS6', 'BULL-1-M-M Loan', 'BULL-2-M-M Loan', 'LEND-BULL', 'OKEX-2-S3', 'BINE-2-S1-M', 'DEFI-STRAT-1 Loan', 'GATE-1-M-M Loan', 'BINE-2-S2-M', 'DEFI-STRAT-8 Loan')
#     and balancetype != 'unrealized'
# order by Account
# ': ('01000', '[01000] [Microsoft][ODBC SQL Server Driver][DBNETLIB]ConnectionWrite (send()). (10054) (SQLExecDirectW); [01000] [Microsoft][ODBC SQL Server Driver][DBNETLIB]General network error. Check your network documentation. (11)')

# %%
# %%capture
# Operations EOD 
op_eod_balances_df = operations_repo.get_eod_balances(nav_date).as_dataframe()
op_eod_balances_df.Currency.replace(*bovas_currency_replacement, inplace=True)
op_eod_balances_df['Notional'] = op_eod_balances_df.Balance * marks_df.reindex(op_eod_balances_df.Currency).fillna(0).Mark.values

# %%
# %%capture
# Exchange balances
#cme_exchange_df = exchange_repo.get_cme_positions(at_dtt_utc=nav_00utc).as_dataframe()
crypto_exchange_df = exchange_repo.get_exchange_balances(asof=nav_ctz).as_dataframe()
crypto_exchange_df['Notional'] = crypto_exchange_df.Balance * marks_df.reindex(crypto_exchange_df.Currency).fillna(0).Mark.values

# %%
# %%capture
# We should properly map accounts to Endpoint or exchange
bovas_assets_df['Endpoint'] = bovas_assets_df['Account'].apply(lambda ac: str(ac.split('-')[0]) if str(ac.split('-')[0]) != 'LEND' else str(ac.split('-')[1]))
bovas_loans_df['Endpoint'] = bovas_loans_df['Account'].apply(lambda ac: str(ac.split('-')[0]) if str(ac.split('-')[0]) != 'LEND' else str(ac.split('-')[1]))
op_eod_balances_df['Endpoint'] = op_eod_balances_df['Account'].apply(lambda ac: str(ac.split('-')[0]) if str(ac.split('-')[0]) != 'LEND' else str(ac.split('-')[1]))
crypto_exchange_df['Endpoint'] = crypto_exchange_df['Account'].apply(lambda ac: str(ac.split('-')[0]) if str(ac.split('-')[0]) != 'LEND' else str(ac.split('-')[1]))

# Add in bank balances; 
bank_eod_balances_df = trading_repo.get_bank_balances(nav_date).as_dataframe()
bank_eod_balances_df['Notional'] = bank_eod_balances_df.Balance * marks_df.reindex(bank_eod_balances_df.Currency).fillna(0).Mark.values
bank_eod_balances_df['Endpoint'] = 'CASH'
bovas_assets_df = pd.concat([bovas_assets_df, bank_eod_balances_df], ignore_index=True)
op_eod_balances_df = pd.concat([op_eod_balances_df, bank_eod_balances_df], ignore_index=True)

# %%
# %%capture
# Add in ED&F collateral manually
edf_cash = generate_daily_summary.get_edf_cash_with_fallback(nav_date)
edf_cash_df = pd.DataFrame.from_dict({
        'Account': ['ED&F Man Capital'], 
        'Balance': [edf_cash], 
        'BalanceType': ['Balance'], 
        'Currency': ['USD'], 
        'Source': [''],
        'Timestamp': [f"{nav_date:%Y%m%d}"],
        'Timestamp_Native': [nav_00utc],
        'Notional': [edf_cash], 
        'Endpoint': ['ED&F']
 })

op_eod_balances_df.drop(op_eod_balances_df.loc[op_eod_balances_df.Account == 'ED&F Man Capital'].index, axis=0, inplace=True)
op_eod_balances_df = pd.concat([op_eod_balances_df, edf_cash_df], ignore_index=True)

bovas_assets_df.drop(bovas_assets_df.loc[bovas_assets_df.Account == 'ED&F Man Capital'].index, axis=0, inplace=True)
bovas_assets_df = pd.concat([bovas_assets_df, edf_cash_df], ignore_index=True)

edf_cash_df.loc[0, 'Timestamp'] = f"{nav_date:%Y-%m-%d}"
crypto_exchange_df.drop(crypto_exchange_df.loc[crypto_exchange_df.Account == 'ED&F Man Capital'].index, axis=0, inplace=True)
crypto_exchange_df = pd.concat([crypto_exchange_df, edf_cash_df], ignore_index=True)

# %%
# display(marks_df)
# display(bovas_loans_df)
# display(bovas_assets_df)
# display(op_eod_balances_df)

# Display DF of all records not used in Bovas's report
op_eod = op_eod_balances_df.copy()
bovas_assets_eod = bovas_assets_df.copy()
bovas_assets_eod = nav.utils._format_assets(nav_date, bovas_assets_eod, marks_df)
bovas_loans_eod = bovas_loans_df.copy()
bovas_loans_eod = nav.utils._format_loans(nav_date, bovas_loans_eod, marks_df)

# Assets - apply the mappings to account names that Bovas's code does
op_eod.loc[((op_eod['Balance'] > 0) | (op_eod['BalanceType'] == 'Unrealized')), 'Account'] \
      = op_eod.loc[((op_eod['Balance'] > 0) | (op_eod['BalanceType'] == 'Unrealized')), 'Account'].replace(*bovas_asset_account_name_replacement)
#bovas_assets_eod.Account.replace(*bovas_asset_account_name_replacement, inplace=True)
#bovas_assets_eod.Currency.replace(*bovas_currency_replacement, inplace=True)

# Loans
op_eod.loc[((op_eod['Balance'] < 0) & (op_eod['BalanceType'] != 'Unrealized')), 'Account'] \
      = op_eod.loc[((op_eod['Balance'] < 0) & (op_eod['BalanceType'] != 'Unrealized')), 'Account'].replace(*bovas_loan_account_name_replacement)
#bovas_loans_eod.Account.replace(*bovas_loan_account_name_replacement, inplace=True)
#bovas_loans_eod.Currency.replace(*bovas_currency_replacement, inplace=True)

# Sum Fireblocks to currency
op_eod = nav.utils._format_fireblocks(op_eod)

df1 = pd.concat([op_eod, bovas_assets_eod, bovas_loans_eod]).set_index(op_eod.columns.tolist())
df2 = pd.concat([bovas_assets_eod, bovas_loans_eod]).set_index(op_eod.columns.tolist())
bovas_ignored_df = df1.loc[df2.index.symmetric_difference(df1.index)].reset_index()

# Get all the bovas cypto position records, without the account name mangling, into one df
#op_eod = op_eod_balances_df.copy()
df1 = pd.concat([op_eod, bovas_ignored_df]).set_index(op_eod.columns.tolist())
df2 = bovas_ignored_df.set_index(op_eod.columns.tolist())
bovas_included_df = df1.loc[df2.index.symmetric_difference(df1.index)].reset_index()

# Three views of the exchange positions
reported_eod_df = reported_eod_balances.copy()
reported_eod_df['Unrealized'] = reported_eod_df.apply(lambda row: row.Notional if row.BalanceType == 'Unrealized' else 0, axis=1)
reported_eod_df['Loans-funding'] = reported_eod_df.apply(lambda row: row.Notional if row.BalanceType != 'Unrealized' and row.Notional < 0 else 0, axis=1)
reported_eod_df['Assets'] = reported_eod_df.apply(lambda row: row.Notional if  row.BalanceType != 'Unrealized' and row.Notional > 0 else 0, axis=1)
report_totals = reported_eod_df[['Timestamp', 'Endpoint', 'Loans-funding', 'Assets', 'Unrealized', 'Notional']].groupby(by=['Timestamp',]).sum(numeric_only=True).reset_index()
report_by_exchange = reported_eod_df[['Timestamp', 'Endpoint', 'Loans-funding', 'Assets', 'Unrealized', 'Notional']].groupby(by=['Timestamp', 'Endpoint',]).sum(numeric_only=True).reset_index()

bovas_df = pd.concat([bovas_assets_eod, bovas_loans_eod], ignore_index=True)
#bovas_df['Endpoint'] = bovas_df['Account'].apply(lambda ac: str(ac.split('-')[0]) if str(ac.split('-')[0]) != 'LEND' else str(ac.split('-')[1]))
bovas_df['Unrealized'] = bovas_df.apply(lambda row: row.Notional if row.BalanceType == 'Unrealized' else 0, axis=1)
bovas_df['Loans-funding'] = bovas_df.apply(lambda row: row.Notional if row.BalanceType != 'Unrealized' and row.Notional < 0 else 0, axis=1)
bovas_df['Assets'] = bovas_df.apply(lambda row: row.Notional if  row.BalanceType != 'Unrealized' and row.Notional > 0 else 0, axis=1)
bovas_totals = bovas_df[['Timestamp', 'Endpoint', 'Loans-funding', 'Assets', 'Unrealized', 'Notional']].groupby(by=['Timestamp',]).sum(numeric_only=True).reset_index()
bovas_by_exchange = bovas_df[['Timestamp', 'Endpoint', 'Loans-funding', 'Assets', 'Unrealized', 'Notional']].groupby(by=['Timestamp', 'Endpoint',]).sum(numeric_only=True).reset_index()

op_eod_df = op_eod.copy()
#op_eod_df['Endpoint'] = op_eod_df['Account'].apply(lambda ac: str(ac.split('-')[0]) if str(ac.split('-')[0]) != 'LEND' else str(ac.split('-')[1]))
op_eod_df['Unrealized'] = op_eod_df.apply(lambda row: row.Notional if row.BalanceType == 'Unrealized' else 0, axis=1)
op_eod_df['Loans-funding'] = op_eod_df.apply(lambda row: row.Notional if row.BalanceType != 'Unrealized' and row.Notional < 0 else 0, axis=1)
op_eod_df['Assets'] = op_eod_df.apply(lambda row: row.Notional if  row.BalanceType != 'Unrealized' and row.Notional > 0 else 0, axis=1)
op_eod_totals = op_eod_df[['Timestamp', 'Endpoint', 'Loans-funding', 'Assets', 'Unrealized', 'Notional']].groupby(by=['Timestamp',]).sum(numeric_only=True).reset_index()
op_eod_by_exchange = op_eod_df[['Timestamp', 'Endpoint', 'Loans-funding', 'Assets', 'Unrealized', 'Notional']].groupby(by=['Timestamp', 'Endpoint',]).sum(numeric_only=True).reset_index()

crypto_eod_df = crypto_exchange_df.copy()
#op_eod_df['Endpoint'] = op_eod_df['Account'].apply(lambda ac: str(ac.split('-')[0]) if str(ac.split('-')[0]) != 'LEND' else str(ac.split('-')[1]))
crypto_eod_df['Unrealized'] = crypto_eod_df.apply(lambda row: row.Notional if row.BalanceType == 'Unrealized' else 0, axis=1)
crypto_eod_df['Loans-funding'] = crypto_eod_df.apply(lambda row: row.Notional if row.BalanceType != 'Unrealized' and row.Notional < 0 else 0, axis=1)
crypto_eod_df['Assets'] = crypto_eod_df.apply(lambda row: row.Notional if  row.BalanceType != 'Unrealized' and row.Notional > 0 else 0, axis=1)
crypto_eod_totals = crypto_eod_df[['Timestamp', 'Endpoint', 'Loans-funding', 'Assets', 'Unrealized', 'Notional']].groupby(by=['Timestamp',]).sum(numeric_only=True).reset_index()
crypto_eod_by_exchange = crypto_eod_df[['Timestamp', 'Endpoint', 'Loans-funding', 'Assets', 'Unrealized', 'Notional']].groupby(by=['Timestamp', 'Endpoint',]).sum(numeric_only=True).reset_index()


print(f"Total Exchange EOD notional balance reported in Bovas's report:  {bovas_included_df.Notional.sum(numeric_only=True):,.0f}"
      f"\tNotional notional balance of EOD records removed from reporting: {bovas_ignored_df.Notional.sum(numeric_only=True):,.0f}\n")

print("Summary from Bovas's code")
display(report_totals)
display(report_by_exchange)

print("Summary from bovas's sql")
display(bovas_totals)
display(bovas_by_exchange)

print("Summary raw data exchange balance tables.")
display(crypto_eod_totals)
display(crypto_eod_by_exchange)

print("Summary from ops table - this shows the size of the effect of double counting, etc, that happens if we ignore finance's exclusions.")
display(op_eod_totals)
display(op_eod_by_exchange)
# Out:
# Total Exchange EOD notional balance reported in Bovas's report:  35,170,344	Notional notional balance of EOD records removed from reporting: 58,989,496
#
# Summary from Bovas's code
# c:\Users\skingham\Projects\galaxysk\qpt_stress_test\nav\utils.py:99: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   temp = temp.groupby(['Account','Currency','BalanceType','Source','Timestamp','Timestamp_Native']).sum().reset_index()
# c:\Users\skingham\Projects\galaxysk\qpt_stress_test\nav\utils.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True)
# c:\Users\skingham\Projects\galaxysk\qpt_stress_test\nav\utils.py:99: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   temp = temp.groupby(['Account','Currency','BalanceType','Source','Timestamp','Timestamp_Native']).sum().reset_index()
# c:\Users\skingham\Projects\galaxysk\qpt_stress_test\nav\utils.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp, ignore_index=True)
#   Timestamp   Loans-funding         Assets    Unrealized      Notional
# 0  20230110 -301,615,194.31 338,102,595.78 -1,097,138.03 35,390,263.43
#    Timestamp     Endpoint   Loans-funding         Assets  Unrealized  \
# 0   20230110         BINE   -1,766,315.47  76,697,936.93 -900,173.93
# 1   20230110        BTFX             0.00         166.39        0.00
# 2   20230110         BTSE            0.00     158,913.08        0.00
# 3   20230110         BULL  -71,253,057.90 119,708,558.04        0.00
# 4   20230110         CASH            0.00     726,247.51        0.00
# 5   20230110         DEFI   -9,992,297.29  14,655,162.85        0.00
# 6   20230110         DYDX            0.00      18,086.75        0.00
# 7   20230110         ED&F            0.00  32,067,740.46        0.00
# 8   20230110         FBLK            0.00  38,497,026.30        0.00
# 9   20230110       GALAXY -207,016,912.36  13,125,191.51        0.00
# 10  20230110         GATE            0.00      20,667.04        0.00
# 11  20230110         HUBI  -10,279,650.30  13,111,031.82   -5,086.35
# 12  20230110         KRKE            0.00     180,033.91        0.00
# 13  20230110         LMAC            0.00           0.67        0.00
# 14  20230110         LMAX            0.00      10,139.55        0.00
# 15  20230110         OKEX     -119,307.99  25,798,390.91 -191,877.75
# 16  20230110       ORCHID   -1,187,582.35           0.00        0.00
# 17  20230110         PITX            0.00           0.98        0.00
# 18  20230110       RIPPLE          -70.66           0.00        0.00
# 19  20230110  SHFT WALLET            0.00      27,800.07        0.00
# 20  20230110      WEDBUSH            0.00      79,941.92        0.00
# 21  20230110         WOOX            0.00   3,219,559.08        0.00
#
#           Notional
# 0    74,031,447.53
# 1           166.39
# 2       158,913.08
# 3    48,455,500.14
# 4       726,247.51
# 5     4,662,865.56
# 6        18,086.75
# 7    32,067,740.46
# 8    38,497,026.30
# 9  -193,891,720.85
# 10       20,667.04
# 11    2,826,295.17
# 12      180,033.91
# 13            0.67
# 14       10,139.55
# 15   25,487,205.17
# 16   -1,187,582.35
# 17            0.98
# 18          -70.66
# 19       27,800.07
# 20       79,941.92
# 21    3,219,559.08
# Summary from bovas's sql
#   Timestamp   Loans-funding         Assets    Unrealized      Notional
# 0  20230110 -301,615,372.02 337,882,854.28 -1,097,138.03 35,170,344.23
#    Timestamp Endpoint   Loans-funding         Assets  Unrealized  \
# 0   20230110     BINE   -1,766,493.18  76,698,041.33 -900,173.93
# 1   20230110     BTFX            0.00         166.39        0.00
# 2   20230110     BTSE            0.00     158,913.08        0.00
# 3   20230110     BULL  -71,253,057.90 119,708,558.04        0.00
# 4   20230110     CASH            0.00     729,344.04        0.00
# 5   20230110     DEFI   -9,992,297.29  14,440,130.10        0.00
# 6   20230110     DYDX            0.00      18,086.75        0.00
# 7   20230110     ED&F            0.00  32,067,740.46        0.00
# 8   20230110     FUB2            0.00          21.21        0.00
# 9   20230110     FUBI            0.00         683.40        0.00
# 10  20230110     GACM -207,016,912.36  13,125,264.69        0.00
# 11  20230110     GATE            0.00      20,667.04        0.00
# 12  20230110     HUB2            0.00           3.26        0.00
# 13  20230110     HUBI  -10,279,650.30  13,110,205.71   -5,086.35
# 14  20230110     KRKE            0.00     180,033.91        0.00
# 15  20230110     LMAC            0.00           0.67        0.00
# 16  20230110     LMAX            0.00      10,139.55        0.00
# 17  20230110     OKEX     -119,307.99  25,798,390.91 -191,877.75
# 18  20230110     OXTF   -1,187,582.35           0.00        0.00
# 19  20230110     PITX            0.00           0.98        0.00
# 20  20230110     SHFT            0.00      99,876.20        0.00
# 21  20230110     WOOX            0.00   3,219,559.08        0.00
# 22  20230110     XRPF          -70.66           0.00        0.00
#
#           Notional
# 0    74,031,374.22
# 1           166.39
# 2       158,913.08
# 3    48,455,500.14
# 4       729,344.04
# 5     4,447,832.81
# 6        18,086.75
# 7    32,067,740.46
# 8            21.21
# 9           683.40
# 10 -193,891,647.67
# 11       20,667.04
# 12            3.26
# 13    2,825,469.06
# 14      180,033.91
# 15            0.67
# 16       10,139.55
# 17   25,487,205.17
# 18   -1,187,582.35
# 19            0.98
# 20       99,876.20
# 21    3,219,559.08
# 22          -70.66
# Summary raw data exchange balance tables.
#     Timestamp  Loans-funding         Assets    Unrealized       Notional
# 0  2023-01-10  -1,892,248.68 296,287,232.02 -1,067,542.67 293,327,440.67
# 1  2023-01-12           0.00      16,969.02          0.00      16,969.02
#      Timestamp             Endpoint  Loans-funding         Assets  Unrealized  \
# 0   2023-01-10                 BINE  -1,768,213.55  76,699,830.25 -902,909.35
# 1   2023-01-10                 BTFX           0.00         201.28        0.00
# 2   2023-01-10                 BTSE           0.00     158,974.81        0.00
# 3   2023-01-10                 BULL           0.00 119,708,498.00        0.00
# 4   2023-01-10                 ED&F           0.00  32,067,740.46        0.00
# 5   2023-01-10                 FBLK           0.00  25,216,441.83        0.00
# 6   2023-01-10                 FUB2           0.00          21.21        0.00
# 7   2023-01-10                 FUBI           0.00         683.40        0.00
# 8   2023-01-10                 HUB2           0.00           3.26        0.00
# 9   2023-01-10                 HUBI           0.00  12,153,132.37     -324.30
# 10  2023-01-10                 KRKE           0.00     179,278.86        0.00
# 11  2023-01-10                 LMAC           0.00     376,890.21        0.00
# 12  2023-01-10                 LMAX           0.00      10,139.37        0.00
# 13  2023-01-10                 OKEX    -124,035.14  25,766,496.82 -164,309.02
# 14  2023-01-10  Silvergate Checking           0.00       4,345.74        0.00
# 15  2023-01-10   Silvergate Network           0.00     724,998.30        0.00
# 16  2023-01-10                 WOOX           0.00   3,219,555.86        0.00
# 17  2023-01-12                 DYDX           0.00      16,969.02        0.00
#
#          Notional
# 0   74,028,707.35
# 1          201.28
# 2      158,974.81
# 3  119,708,498.00
# 4   32,067,740.46
# 5   25,216,441.83
# 6           21.21
# 7          683.40
# 8            3.26
# 9   12,152,808.08
# 10     179,278.86
# 11     376,890.21
# 12      10,139.37
# 13  25,478,152.66
# 14       4,345.74
# 15     724,998.30
# 16   3,219,555.86
# 17      16,969.02
# Summary from ops table - this shows the size of the effect of double counting, etc, that happens if we ignore finance's exclusions.
#   Timestamp   Loans-funding         Assets    Unrealized      Notional
# 0  20230110 -317,171,330.62 412,428,308.50 -1,097,138.03 94,159,839.85
#    Timestamp Endpoint   Loans-funding         Assets  Unrealized  \
# 0   20230110     BINE   -1,766,493.18  76,698,041.33 -900,173.93
# 1   20230110     BTFX            0.00         166.39        0.00
# 2   20230110     BTGO   -3,489,294.15           0.00        0.00
# 3   20230110     BTSE            0.00     158,913.08        0.00
# 4   20230110     BULL  -71,253,057.90 119,708,558.04        0.00
# 5   20230110     CASH            0.00     729,344.04        0.00
# 6   20230110     DEFI   -9,992,297.29  37,818,558.71        0.00
# 7   20230110     DYDX            0.00      18,086.75        0.00
# 8   20230110     ED&F            0.00  32,067,740.46        0.00
# 9   20230110     FBLK            0.00  22,297,524.33        0.00
# 10  20230110     FUB2            0.00          21.21        0.00
# 11  20230110     FUBI            0.00         683.40        0.00
# 12  20230110     GACM -207,016,912.36  13,125,264.69        0.00
# 13  20230110     GATE            0.00      20,667.04        0.00
# 14  20230110     GENX   -3,367,134.28           0.00        0.00
# 15  20230110     GOTC   -6,694,651.00  28,869,501.29        0.00
# 16  20230110     HUB2            0.00           3.26        0.00
# 17  20230110     HUBI  -10,279,650.30  13,110,205.71   -5,086.35
# 18  20230110     KRKE            0.00     180,033.91        0.00
# 19  20230110     LMAC            0.00           0.67        0.00
# 20  20230110     LMAX            0.00      10,139.55        0.00
# 21  20230110     NICO   -2,004,879.17           0.00        0.00
# 22  20230110     OKEX     -119,307.99  25,798,390.91 -191,877.75
# 23  20230110     OXTF   -1,187,582.35           0.00        0.00
# 24  20230110     PITX            0.00           0.98        0.00
# 25  20230110     SHFT            0.00      99,876.20        0.00
# 26  20230110     WOOX            0.00   3,219,559.08        0.00
# 27  20230110     XRPF          -70.66           0.00        0.00
#
#           Notional
# 0    74,031,374.22
# 1           166.39
# 2    -3,489,294.15
# 3       158,913.08
# 4    48,455,500.14
# 5       729,344.04
# 6    27,826,261.42
# 7        18,086.75
# 8    32,067,740.46
# 9    22,297,524.33
# 10           21.21
# 11          683.40
# 12 -193,891,647.67
# 13       20,667.04
# 14   -3,367,134.28
# 15   22,174,850.30
# 16            3.26
# 17    2,825,469.06
# 18      180,033.91
# 19            0.67
# 20       10,139.55
# 21   -2,004,879.17
# 22   25,487,205.17
# 23   -1,187,582.35
# 24            0.98
# 25       99,876.20
# 26    3,219,559.08
# 27          -70.66

# %%
print("Operations.balances.EndOfDay_00UTC records that are not included in Bovas's NAV report:")
display(bovas_ignored_df.sort_values(by=['Account', 'Currency'], ignore_index=True))

print("\nOperations.balances.EndOfDay_00UTC records that are included in Bovas's NAV report:")
display(bovas_included_df.sort_values(by=['Account', 'Currency'], ignore_index=True))
# Out:
# Operations.balances.EndOfDay_00UTC records that are not included in Bovas's NAV report:
#                Account        Balance            BalanceType  \
# 0         DEFI-STRAT-4         628.99           reward_token
# 1         DEFI-STRAT-4         175.24           reward_token
# 2         DEFI-STRAT-4         414.32           supply_token
# 3         DEFI-STRAT-4         598.84           supply_token
# 4         DEFI-STRAT-8  12,008,983.85                 wallet
# 5         DEFI-STRAT-8           1.88                 wallet
# 6         DEFI-STRAT-8           0.46                 wallet
# 7         DEFI-STRAT-8      33,055.56                 wallet
# 8         DEFI-STRAT-8   9,991,297.76                 wallet
# 9   FBLK-DEFI-STRAT001           9.78
# 10  FBLK-DEFI-STRAT001           3.67
# 11  FBLK-DEFI-STRAT001           3.64
# 12  FBLK-DEFI-STRAT001      13,972.22
# 13  FBLK-DEFI-STRAT002         129.80
# 14  FBLK-DEFI-STRAT002           9.01
# 15  FBLK-DEFI-STRAT002          16.88
# 16  FBLK-DEFI-STRAT002           0.00
# 17  FBLK-DEFI-STRAT002      34,311.93
# 18  FBLK-DEFI-STRAT002      32,302.94
# 19  FBLK-DEFI-STRAT002      32,626.54
# 20  FBLK-DEFI-STRAT002      33,793.38
# 21  FBLK-DEFI-STRAT002      33,991.37
# 22  FBLK-DEFI-STRAT002      19,597.43
# 23  FBLK-DEFI-STRAT002      29,214.15
# 24  FBLK-DEFI-STRAT002      20,213.41
# 25  FBLK-DEFI-STRAT002      31,925.00
# 26  FBLK-DEFI-STRAT002      17,599.94
# 27  FBLK-DEFI-STRAT002       3,032.00
# 28  FBLK-DEFI-STRAT002       2,698.00
# 29  FBLK-DEFI-STRAT002       2,891.00
# 30  FBLK-DEFI-STRAT002       2,904.00
# 31  FBLK-DEFI-STRAT002       9,472.13
# 32  FBLK-DEFI-STRAT002       5,625.03
# 33  FBLK-DEFI-STRAT002       5,968.00
# 34  FBLK-DEFI-STRAT002       4,006.00
# 35  FBLK-DEFI-STRAT002      60,000.00
# 36  FBLK-DEFI-STRAT002          76.89
# 37  FBLK-DEFI-STRAT002         128.59
# 38  FBLK-DEFI-STRAT003       4,430.17
# 39  FBLK-DEFI-STRAT003           0.56
# 40  FBLK-DEFI-STRAT003         538.74
# 41  FBLK-DEFI-STRAT004           2.35
# 42  FBLK-DEFI-STRAT005           0.10
# 43  FBLK-DEFI-STRAT005     196,525.25
# 44  FBLK-DEFI-STRAT005     201,000.92
# 45  FBLK-DEFI-STRAT005 100,050,250.67
# 46  FBLK-DEFI-STRAT006           5.15
# 47  FBLK-DEFI-STRAT006         296.85
# 48  FBLK-DEFI-STRAT008  12,008,527.17
# 49  FBLK-DEFI-STRAT008           1.88
# 50  FBLK-DEFI-STRAT008           0.46
# 51  FBLK-DEFI-STRAT008   9,990,233.13
# 52           GOTC-BIGO          -0.05  Unsettled Obligations
# 53           GOTC-BIGO          -0.39  Unsettled Obligations
# 54           GOTC-BIGO          -0.26  Unsettled Obligations
# 55           GOTC-BIGO          -0.01  Unsettled Obligations
# 56           GOTC-BIGO           0.05  Unsettled Obligations
# 57           GOTC-BIGO    -976,154.23  Unsettled Obligations
# 58           GOTC-BIGO          -0.00  Unsettled Obligations
# 59           GOTC-GACM         251.38  Unsettled Obligations
# 60           GOTC-GACM      74,597.20  Unsettled Obligations
# 61           GOTC-GACM      28,194.16  Unsettled Obligations
# 62           GOTC-GACM       2,644.76  Unsettled Obligations
# 63           GOTC-GACM      -1,790.27  Unsettled Obligations
# 64           GOTC-GACM         217.62  Unsettled Obligations
# 65           GOTC-GACM        -286.71  Unsettled Obligations
# 66           GOTC-GACM         -11.70  Unsettled Obligations
# 67           GOTC-GACM          24.29  Unsettled Obligations
# 68           GOTC-GACM     449,851.20  Unsettled Obligations
# 69           GOTC-GACM       4,710.00  Unsettled Obligations
# 70           GOTC-GACM      13,936.11  Unsettled Obligations
# 71           GOTC-GACM      30,050.00  Unsettled Obligations
# 72           GOTC-GACM        -417.23  Unsettled Obligations
# 73           GOTC-GACM    -135,193.37  Unsettled Obligations
# 74           GOTC-GACM      33,870.87  Unsettled Obligations
# 75           GOTC-GACM      50,000.00  Unsettled Obligations
# 76           GOTC-GACM      89,570.55  Unsettled Obligations
# 77           GOTC-GACM       6,861.48  Unsettled Obligations
# 78           GOTC-GACM         274.87  Unsettled Obligations
# 79           GOTC-GACM      44,970.84  Unsettled Obligations
# 80           GOTC-GACM      47,881.79  Unsettled Obligations
# 81           GOTC-GACM          -8.78  Unsettled Obligations
# 82           GOTC-GACM          -1.46  Unsettled Obligations
# 83           GOTC-GACM      80,000.00  Unsettled Obligations
# 84           GOTC-GACM  81,832,884.83  Unsettled Obligations
# 85           GOTC-GACM       1,874.13  Unsettled Obligations
# 86           GOTC-GACM      21,418.16  Unsettled Obligations
# 87           GOTC-GACM       4,481.79  Unsettled Obligations
# 88           GOTC-GACM  28,380,699.81  Unsettled Obligations
# 89           GOTC-GACM      57,683.49  Unsettled Obligations
# 90           GOTC-GACM           0.33  Unsettled Obligations
# 91           GOTC-GACM      83,471.08  Unsettled Obligations
# 92           GOTC-GACM       4,681.39  Unsettled Obligations
# 93           GOTC-GACM          -0.03  Unsettled Obligations
# 94           LEND-BTGO        -200.00
# 95           LEND-BTGO          -0.00
# 96           LEND-BTGO        -100.00
# 97           LEND-GENX        -193.00
# 98           LEND-NICO      -1,500.00
#
#                                        Currency            Source Timestamp  \
# 0                                          AURA                    20230110
# 1                                           BAL                    20230110
# 2                                           ETH                    20230110
# 3                                         STETH                    20230110
# 4                                         AUSDC                    20230110
# 5                                          AVAX                    20230110
# 6                                           ETH                    20230110
# 7                                          USDT                    20230110
# 8                                          USDT                    20230110
# 9                                           CRV                    20230110
# 10                                          ETH                    20230110
# 11                                         ETHW                    20230110
# 12                                         USDC                    20230110
# 13                                         AAVE                    20230110
# 14                                         AVAX                    20230110
# 15                                          ETH                    20230110
# 16                                         ETHW                    20230110
# 17        OAAVEUSDC_AAVE-02DEC22-67_5C_ETH_VR7K                    20230110
# 18        OAAVEUSDC_AAVE-06JAN23-62_5C_ETH_6UBB                    20230110
# 19        OAAVEUSDC_AAVE-13JAN23-62_5C_ETH_OZQM                    20230110
# 20        OAAVEUSDC_AAVE-16DEC22-72_5C_ETH_NF7H                    20230110
# 21        OAAVEUSDC_AAVE-25NOV22-72_5C_ETH_IV8T                    20230110
# 22  OWAVAXUSDC_E_WAVAX-06JAN23-12_25C_AVAX_OCWN                    20230110
# 23   OWAVAXUSDC_E_WAVAX-09DEC22-15_5C_AVAX_M135                    20230110
# 24  OWAVAXUSDC_E_WAVAX-16DEC22-15_25C_AVAX_EN88                    20230110
# 25   OWAVAXUSDC_E_WAVAX-25NOV22-15_5C_AVAX_QGUL                    20230110
# 26  OWAVAXUSDC_E_WAVAX-30DEC22-13_25C_AVAX_W9CA                    20230110
# 27        OWETHUSDC_WETH-06JAN23-1300C_ETH_AUPP                    20230110
# 28        OWETHUSDC_WETH-09DEC22-1450C_ETH_OWE6                    20230110
# 29        OWETHUSDC_WETH-16DEC22-1450C_ETH_52GN                    20230110
# 30        OWETHUSDC_WETH-25NOV22-1400C_ETH_SFAI                    20230110
# 31      OWETHUSDC_WSTETH-02DEC22-1350C_ETH_1LRC                    20230110
# 32      OWETHUSDC_WSTETH-04NOV22-1700C_ETH_SWAA                    20230110
# 33      OWETHUSDC_WSTETH-09SEP22-1900C_ETH_1Z8K                    20230110
# 34      OWETHUSDC_WSTETH-30DEC22-1350C_ETH_2DDK                    20230110
# 35                                         USDC                    20230110
# 36                                   WAVAX_AVAX                    20230110
# 37                                         WETH                    20230110
# 38                                          CRV                    20230110
# 39                                          ETH                    20230110
# 40                                         USDC                    20230110
# 41                                          ETH                    20230110
# 42                                          ETH                    20230110
# 43           OBALUSDC_BAL-30DEC22-7_6C_ETH_9HM7                    20230110
# 44        OPERPUSDC_PERP-30DEC22-0_54C_ETH_810N                    20230110
# 45   OSPELLUSDC_SPELL-30DEC22-0_00079C_ETH_L34N                    20230110
# 37               BINE-2-S1-E               0.10
# 38               BINE-2-S1-E      18,966,318.77
# 39               BINE-2-S1-F             -16.10    Unrealized
# 40               BINE-2-S1-F             844.15       Balance
# 41               BINE-2-S1-F            -200.37    Unrealized
# 42               BINE-2-S1-F           6,744.21       Balance
# 43               BINE-2-S1-M           2,496.50
# 44               BINE-2-S1-M             455.42
# 45               BINE-2-S1-M       3,589,761.82
# 46               BINE-2-S1-M               0.16
# 47               BINE-2-S1-M           4,692.23
# 48               BINE-2-S1-M       3,181,892.17
# 49   BINE-2-S1-M Margin Loan            -900.00
# 50   BINE-2-S1-M Margin Loan        -450,000.00
# 51   BINE-2-S1-M Margin Loan        -244,800.00
# 52   BINE-2-S1-M Margin Loan          -6,000.00
# 53   BINE-2-S1-M Margin Loan        -200,000.00
# 54   BINE-2-S1-M Margin Loan             -90.00
# 55   BINE-2-S1-M Margin Loan          -4,800.00
# 56   BINE-2-S1-M Margin Loan          -1,000.00
# 57   BINE-2-S1-M Margin Loan      -1,100,000.00
# 58   BINE-2-S1-M Margin Loan         -10,000.00
# 59   BINE-2-S1-M Margin Loan         -60,000.00
# 60   BINE-2-S1-M Margin Loan         -75,171.80
# 61   BINE-2-S1-M Margin Loan        -300,000.00
# 62   BINE-2-S1-M Margin Loan        -240,000.00
# 63   BINE-2-S1-M Margin Loan        -628,800.00
# 64   BINE-2-S1-M Margin Loan         -20,634.49
# 65   BINE-2-S1-M Margin Loan          -1,503.12
# 66   BINE-2-S1-M Margin Loan         -90,000.00
# 67   BINE-2-S1-M Margin Loan        -100,000.00
# 68   BINE-2-S1-M Margin Loan             -14.00
# 69   BINE-2-S1-M Margin Loan  -6,000,000,000.00
# 70   BINE-2-S1-M Margin Loan          -8,500.00
# 71   BINE-2-S1-M Margin Loan         -43,200.00
# 72   BINE-2-S1-M Margin Loan         -12,000.00
# 73   BINE-2-S1-M Margin Loan            -100.00
# 74   BINE-2-S1-M Margin Loan      -1,000,000.00
# 75   BINE-2-S1-M Margin Loan         -68,160.00
# 76               BINE-2-S1-P              48.46       Balance
# 77               BINE-2-S1-P      16,000,004.79       Balance
# 78               BINE-2-S1-P        -358,313.53    Unrealized
# 79               BINE-2-S1-P      11,118,239.43       Balance
# 80               BINE-2-S2-P           6,817.37    Unrealized
# 81               BINE-2-S2-P         757,840.91       Balance
# 82                       BMO               0.00          Cash
# 83                       BMO               0.00          Cash
# 84                       BMO               0.00          Cash
# 85                       BMO               0.00          Cash
# 86                BTFX-1-M-E               0.01
# 87                BTFX-1-M-E               0.02
# 88                BTFX-1-M-E               0.02
# 89                BTFX-1-M-E               0.03
# 90                BTFX-1-M-E              29.99
# 91                      BTSE               0.22
# 92                      BTSE               0.06
# 93                      BTSE               0.74
# 94                      BTSE          22,277.53
# 95                      BTSE          22,277.53
# 96                      BTSE         114,736.84
# 97                      BTSE         116,647.68
# 98                BULL-1-M-E           2,083.70
# 99                BULL-1-M-E      42,540,511.73
# 100               BULL-2-M-E       4,640,452.77
# 101               BULL-2-M-E          90,629.12
# 102               BULL-2-M-E           7,661.70
# 103               BULL-2-M-E       3,108,660.64
# 104               BULL-3-M-E           9,505.92
# 105               BULL-3-M-E      16,812,470.56
# 106               BULL-4-M-E              71.58
# 107               BULL-4-M-E           1,023.44
# 108               BULL-4-M-E               0.50
# 109             DEFI-STRAT-1               0.27  reward_token
# 110             DEFI-STRAT-1               9.78        wallet
# 111             DEFI-STRAT-1               0.03  reward_token
# 112             DEFI-STRAT-1               3.67        wallet
# 113             DEFI-STRAT-1          13,972.22        wallet
# 114             DEFI-STRAT-2         180,000.00        wallet
# 115             DEFI-STRAT-2           7,000.00        wallet
# 116             DEFI-STRAT-2           7,000.00        wallet
# 117             DEFI-STRAT-2           7,000.00        wallet
# 118             DEFI-STRAT-2               8.00        wallet
# 119             DEFI-STRAT-2             129.80        wallet
# 120             DEFI-STRAT-2               9.01        wallet
# 121             DEFI-STRAT-2              25.00        wallet
# 122             DEFI-STRAT-2              16.88        wallet
# 123             DEFI-STRAT-2         480,000.00        wallet
# 124             DEFI-STRAT-2          34,311.93        wallet
# 125             DEFI-STRAT-2          32,302.94        wallet
# 126             DEFI-STRAT-2          32,626.54        wallet
# 127             DEFI-STRAT-2          33,793.38        wallet
# 128             DEFI-STRAT-2          33,991.37        wallet
# 129             DEFI-STRAT-2          19,597.43        wallet
# 130             DEFI-STRAT-2          29,214.15        wallet
# 131             DEFI-STRAT-2          20,213.41        wallet
# 132             DEFI-STRAT-2          31,925.00        wallet
# 133             DEFI-STRAT-2          17,599.94        wallet
# 134             DEFI-STRAT-2           3,032.00        wallet
# 135             DEFI-STRAT-2           2,698.00        wallet
# 136             DEFI-STRAT-2           2,891.00        wallet
# 137             DEFI-STRAT-2           2,904.00        wallet
# 138             DEFI-STRAT-2           3,047.00        wallet
# 139             DEFI-STRAT-2           9,472.13        wallet
# 140             DEFI-STRAT-2           5,625.03        wallet
# 141             DEFI-STRAT-2           5,968.00        wallet
# 142             DEFI-STRAT-2           4,006.00        wallet
# 143             DEFI-STRAT-2          60,000.00        wallet
# 144             DEFI-STRAT-2             186.89        wallet
# 145             DEFI-STRAT-2             128.59        wallet
# 146             DEFI-STRAT-3           4,430.17        wallet
# 147             DEFI-STRAT-3           4,581.69  reward_token
# 148             DEFI-STRAT-3             147.42  reward_token
# 149             DEFI-STRAT-3         156,950.95  supply_token
# 150             DEFI-STRAT-3               0.56        wallet
# 151             DEFI-STRAT-3         513,137.02  supply_token
# 152             DEFI-STRAT-3             538.74        wallet
# 153             DEFI-STRAT-3         186,682.32  supply_token
# 154             DEFI-STRAT-3         149,736.27  supply_token
# 155             DEFI-STRAT-4               2.35        wallet
# 156             DEFI-STRAT-5               0.10        wallet
# 157             DEFI-STRAT-5         196,525.25        wallet
# 158             DEFI-STRAT-5         201,000.92        wallet
# 159             DEFI-STRAT-5     100,050,250.67        wallet
# 160             DEFI-STRAT-6           4,740.53  reward_token
# 161             DEFI-STRAT-6             316.72  reward_token
# 162             DEFI-STRAT-6               5.15        wallet
# 163             DEFI-STRAT-6             495.85  supply_token
# 164             DEFI-STRAT-6             501.37  supply_token
# 165             DEFI-STRAT-6             296.85        wallet
# 166             DEFI-STRAT-6             334.80  reward_token
# 167             DEFI-STRAT-8      12,008,983.85  supply_token
# 168        DEFI-STRAT-8 Loan      -9,991,297.76  borrow_token
# 169               DYDX-1-M-P          18,086.97
# 170         ED&F Man Capital      32,067,740.46       Balance
# 171                     FBLK               1.35
# 172                     FBLK             559.00
# 173                     FBLK           6,816.84
# 174                     FBLK              90.22
# 175                     FBLK           6,133.33
# 176                     FBLK           5,331.09
# 177                     FBLK               0.00
# 178                     FBLK             409.19
# 179                     FBLK           2,928.16
# 180                     FBLK               3.01
# 181                     FBLK          18,503.76
# 182                     FBLK             108.57
# 183                     FBLK           1,923.88
# 184                     FBLK         186,334.71
# 185                     FBLK          98,844.46
# 186                     FBLK             958.03
# 187                     FBLK           1,268.18
# 188                     FBLK         235,746.13
# 189                     FBLK          54,170.77
# 190                     FBLK               2.54
# 191                     FBLK          15,952.28
# 192                     FBLK          59,292.76
# 193                     FBLK               0.01
# 194                     FBLK             896.22
# 195                     FBLK              15.92
# 196                     FBLK             606.09
# 197                     FBLK           2,709.70
# 198                     FBLK               0.63
# 199                     FBLK             168.05
# 200                     FBLK         837,715.32
# 201                     FBLK 168,226,902,448.37
# 202                     FBLK              55.75
# 203                     FBLK             544.77
# 204                     FBLK              20.98
# 205                     FBLK      11,975,225.42
# 206                     FBLK      13,311,023.80
# 207                     FBLK          12,011.60
# 208                     FBLK             283.59
# 209                     FBLK             997.64
# 210                     FBLK               4.20
# 211                   FUB2-M               0.00       Balance
# 212                   FUB2-M               0.00       Balance
# 213                   FUB2-M               0.47       Balance
# 214                   FUB2-M               0.00       Balance
# 215                   FUB2-M               0.00       Balance
# 216                   FUB2-M               0.00       Balance
# 217                   FUB2-M               0.00       Balance
# 218                   FUB2-M               0.00       Balance
# 219                   FUB2-M               0.00       Balance
# 220                   FUB2-M               0.00       Balance
# 221                   FUBI-M               0.01       Balance
# 222                   FUBI-M               0.73       Balance
# 223                   FUBI-M               0.11       Balance
# 224                   FUBI-M               0.00       Balance
# 225                   FUBI-M               0.98       Balance
# 226                   FUBI-M               0.04       Balance
# 227                   FUBI-M               0.71       Balance
# 228                   FUBI-M               0.00       Balance
# 229                   FUBI-M               0.06       Balance
# 230                   FUBI-M               7.16       Balance
# 231                   FUBI-M               0.96       Balance
# 232                   FUBI-M               0.54       Balance
# 233               GATE-1-M-C               0.00
# 234               GATE-1-M-C          10,195.01
# 235               GATE-1-M-E               0.02
# 236               GATE-1-M-E               0.00
# 237               GATE-1-M-E               0.00
# 238               GATE-1-M-E               0.00
# 239               GATE-1-M-E              27.16
# 240               GATE-1-M-M               0.00
# 241               GATE-1-M-M               0.00
# 242               GATE-1-M-M              59.39
# 243              GATE-1-M-PT          10,045.41
# 244                   HUB2-E               0.00
# 245                   HUB2-E               0.00
# 246                   HUB2-M               0.00
# 247                   HUB2-M               0.00
# 248                   HUB2-M               0.00
# 249                   HUB2-M               0.00
# 250                   HUB2-M               0.00
# 251                   HUB2-M               0.00
# 252                   HUB2-M               0.00
# 253                   HUB2-M               0.00
# 254                   HUB2-M               3.26
# 255                   HUB2-M               0.00
# 256               HUBI-1-M-P               0.10       Balance
# 257               HUBI-1-M-P               0.00       Balance
# 258               HUBI-1-M-P               0.00       Balance
# 259               HUBI-1-M-P               0.00       Balance
# 260               HUBI-1-M-P              -0.30    Unrealized
# 261               HUBI-1-M-P              19.46       Balance
# 262               HUBI-1-M-P               0.00       Balance
# 263               HUBI-1-M-P               0.10       Balance
# 264               HUBI-1-M-P              -0.01    Unrealized
# 265               HUBI-1-M-P             147.74       Balance
# 266               HUBI-1-M-P               0.00       Balance
# 267               HUBI-1-M-P               0.00       Balance
# 268               HUBI-1-M-P          71,073.21       Balance
# 269               HUBI-1-M-P               0.00       Balance
# 270               HUBI-1-M-P               0.00       Balance
# 271               HUBI-1-M-P               0.00       Balance
# 272              HUBI-1-M-PT             194.14    Unrealized
# 273              HUBI-1-M-PT          36,696.17       Balance
# 274                   HUBI-E             377.10
# 275                   HUBI-E               0.00
# 276                   HUBI-E               0.00
# 277                   HUBI-E               0.53
# 278                   HUBI-E               0.04
# 279                   HUBI-E               0.02
# 280                   HUBI-E               0.02
# 281                   HUBI-E              12.73
# 282                   HUBI-E               0.00
# 283                   HUBI-E             115.30
# 284                   HUBI-E              14.75
# 285                   HUBI-E               0.00
# 286                   HUBI-E              32.73
# 287                   HUBI-E               0.34
# 288                   HUBI-E   1,367,501,156.88
# 289                   HUBI-E               1.79
# 290                   HUBI-E               0.31
# 291                   HUBI-E               0.00
# 292                   HUBI-E               0.00
# 293                   HUBI-E          40,066.77
# 294                   HUBI-E               0.00
# 295                   HUBI-E           5,058.67
# 296                   HUBI-E           8,854.52
# 297                   HUBI-E           4,072.12
# 298                   HUBI-E           9,823.84
# 299                   HUBI-E           3,460.93
# 300                   HUBI-E         107,676.90
# 301                   HUBI-E               1.02
# 302                   HUBI-E       1,214,222.24
# 303                   HUBI-E               0.69
# 304                   HUBI-E              54.78
# 305                   HUBI-E               0.03
# 306                   HUBI-E           5,337.70
# 307                   HUBI-E           1,649.29
# 308                   HUBI-E              14.79
# 309                   HUBI-E               0.82
# 310                   HUBI-E               9.11
# 311                   HUBI-E               0.00
# 312                   HUBI-E               0.24
# 313                   HUBI-E               0.00
# 314                   HUBI-E             520.98
# 315                   HUBI-E               4.33
# 316                   HUBI-E           7,645.74
# 317                   HUBI-E               0.66
# 318                   HUBI-E               0.34
# 319                   HUBI-E               0.89
# 320                   HUBI-E              40.70
# 321                   HUBI-E   3,049,025,070.20
# 322                   HUBI-E               0.00
# 323                   HUBI-E               0.35
# 324                   HUBI-E          50,114.04
# 325                   HUBI-E               0.00
# 326                   HUBI-E               0.03
# 327                   HUBI-E       1,214,222.24
# 328                   HUBI-E       1,884,988.30
# 329                   HUBI-E               0.14
# 330                   HUBI-E          38,753.77
# 331                   HUBI-E              29.76
# 332                   HUBI-E              44.27
# 333                   HUBI-E               0.06
# 334                   HUBI-E              20.00
# 335                   HUBI-E               0.00
# 336                   HUBI-E               0.00
# 337                   HUBI-E               0.35
# 338                   HUBI-E       5,268,656.75
# 339                   HUBI-E              25.96
# 340                   HUBI-E               0.21
# 341                   HUBI-E      97,856,389.90
# 342                   HUBI-E               0.56
# 343                   HUBI-E             545.26
# 344                   HUBI-E               3.93
# 345                   HUBI-E               0.01
# 346                   HUBI-E               0.00
# 347                   HUBI-E       1,306,841.02
# 348                   HUBI-M               0.00
# 349                   HUBI-M               0.00
# 350                   HUBI-M               0.00
# 351                   HUBI-M               0.00
# 352                   HUBI-M               0.91
# 353                   HUBI-M               0.00
# 354                     KRKE               0.33
# 355                     KRKE               1.77
# 356                     KRKE               0.02
# 357                     KRKE               9.95
# 358                     KRKE               3.40
# 359                     KRKE               9.14
# 360                     KRKE         704,924.42
# 361                     KRKE               0.11
# 362                     KRKE         127,892.89
# 363                     KRKE               0.01
# 364                     KRKE               0.01
# 365                     KRKE               0.72
# 366                LEND-BULL          -3,350.00
# 367                LEND-BULL      -4,350,822.18
# 368                LEND-BULL          -6,499.99
# 369                LEND-GACM             300.00
# 370                LEND-GACM         150,000.00
# 371                LEND-GACM          35,000.00
# 372                LEND-GACM           3,000.00
# 373                LEND-GACM         100,000.00
# 374                LEND-GACM           5,627.00
# 375                LEND-GACM          -1,340.02
# 376                LEND-GACM             100.00
# 377                LEND-GACM         600,000.00
# 378                LEND-GACM           5,000.00
# 379                LEND-GACM          15,000.00
# 380                LEND-GACM          30,000.00
# 381                LEND-GACM          98,000.00
# 382                LEND-GACM         -25,855.00
# 383                LEND-GACM     -15,000,000.00
# 384                LEND-GACM          30,000.00
# 385                LEND-GACM          50,000.00
# 386                LEND-GACM         125,000.00
# 387                LEND-GACM           7,000.00
# 388                LEND-GACM             500.00
# 389                LEND-GACM          45,000.00
# 390                LEND-GACM          50,000.00
# 391                LEND-GACM          80,000.00
# 392                LEND-GACM           3,500.00
# 393                LEND-GACM          21,600.00
# 394                LEND-GACM           6,000.00
# 395                LEND-GACM     -42,800,000.00
# 396                LEND-GACM     -89,706,000.00
# 397                LEND-GACM      10,000,000.00
# 398                LEND-GACM         100,000.00
# 399                LEND-GACM           5,000.00
# 400                LEND-GACM     -20,000,000.00
# 401                LEND-HUBI          -5,000.00
# 402                LEND-HUBI         -40,000.00
# 403                LEND-HUBI        -160,000.00
# 404                LEND-HUBI        -108,000.00
# 405                LEND-HUBI          -4,600.00
# 406                LEND-HUBI         -17,000.00
# 407                LEND-HUBI         -11,800.00
# 408                LEND-OXTF      -2,600,208.00
# 409                LEND-OXTF      -1,000,000.00
# 410                LEND-XRPF            -201.17
# 411                     LMAC               0.00
# 412                     LMAC               0.00
# 413                     LMAX          10,139.55
# 414                 OKEX-2-M             -10.14    Unrealized
# 415                 OKEX-2-M             537.40       Balance
# 416                 OKEX-2-M            -236.23    Unrealized
# 417                 OKEX-2-M           9,004.60       Balance
# 418                 OKEX-2-M         614,997.29       Balance
# 419                 OKEX-2-M         319,290.61    Unrealized
# 420                 OKEX-2-M       4,223,618.71       Balance
# 421                 OKEX-2-M           5,054.24       Balance
# 422                 OKEX-2-M       3,281,261.71       Balance
# 423     OKEX-2-M Margin Loan              -3.60       Balance
# 424     OKEX-2-M Margin Loan         -17,034.92       Balance
# 425     OKEX-2-M Margin Loan              -0.04       Balance
# 426     OKEX-2-M Margin Loan            -123.20       Balance
# 427     OKEX-2-M Margin Loan -10,046,478,485.07       Balance
# 428               OKEX-2-M-W               0.00       Balance
# 429               OKEX-2-M-W               0.00       Balance
# 430               OKEX-2-M-W               0.00       Balance
# 431               OKEX-2-M-W               0.00       Balance
# 432               OKEX-2-M-W               0.00       Balance
# 433               OKEX-2-M-W               0.00       Balance
# ...
# 433      okex_2_u1.funding_asset_balance  20230110 2023-01-11 00:00:00.157
# 434      okex_2_u1.funding_asset_balance  20230110 2023-01-11 00:00:00.157
# 435      okex_2_u1.funding_asset_balance  20230110 2023-01-11 00:00:00.157
# 436            okex_2_s1.account_balance  20230110 2023-01-11 00:00:00.323
# 437            okex_2_s1.account_balance  20230110 2023-01-11 00:00:00.323
# 438            okex_2_s1.account_balance  20230110 2023-01-11 00:00:00.323
# 439            okex_2_s2.account_balance  20230110 2023-01-11 00:00:00.430
# 440                                       20230110 2023-01-11 00:00:00.443
# 441                                       20230110 2023-01-11 00:00:00.443
# 442                                       20230110 2023-01-11 00:00:00.443
# 443                                       20230110 2023-01-10 22:21:51.533
# 444                                       20230110 2023-01-10 22:21:51.533
# 445                                       20230110 2023-01-10 22:21:51.533
# 446                                       20230110 2023-01-10 22:21:51.550
# 447                                       20230110 2023-01-10 22:21:51.533
# 448                                       20230110 2023-01-10 22:21:51.533
# 449                                       20230110 2023-01-10 22:21:51.533
# 450                                       20230110 2023-01-11 00:00:00.473
# 451                  crypto.bankbalances  20230110 2023-01-11 07:45:07.223
# 452                  crypto.bankbalances  20230110 2023-01-11 07:45:07.223
# 453                  crypto.bankbalances  20230110 2023-01-10 16:00:00.000
# 454                  crypto.bankbalances  20230110 2023-01-10 16:00:00.000
# 455                  crypto.bankbalances  20230110 2023-01-10 16:00:00.000
# 456                                       20230110 2023-01-11 00:00:00.447
# 457                                       20230110 2023-01-11 00:00:00.447
# 458                                       20230110 2023-01-11 00:00:00.447
# 459                                       20230110 2023-01-11 00:00:00.447
#
#           Notional Endpoint
# 0        36,960.37     BINE
# 1        98,617.54     BINE
# 2        42,203.53     BINE
# 3             0.05     BINE
# 4        32,217.30     BINE
# 5        18,471.85     BINE
# 6        40,559.18     BINE
# 7        11,316.13     BINE
# 8        86,098.94     BINE
# 9           267.21     BINE
# 10       73,077.36     BINE
# 11            0.01     BINE
# 12       43,396.20     BINE
# 13       37,589.76     BINE
# 14       23,621.92     BINE
# 15       12,531.23     BINE
# 16       85,364.32     BINE
# 17       40,948.59     BINE
# 18      856,707.25     BINE
# 19            0.74     BINE
# 20       52,656.86     BINE
# 21       12,644.40     BINE
# 22       22,500.56     BINE
# 23       44,319.56     BINE
# 24       76,464.87     BINE
# 25       21,480.93     BINE
# 26       40,273.83     BINE
# 27       12,060.46     BINE
# 28       27,551.18     BINE
# 29       23,595.65     BINE
# 30      218,100.62     BINE
# 31       80,984.94     BINE
# 32       23,743.20     BINE
# 33       43,505.96     BINE
# 34      561,590.65     BINE
# 35       71,344.20     BINE
# 36       51,758.42     BINE
# 37          568.21     BINE
# 38      454,949.57     BINE
# 39     -280,832.43     BINE
# 40   14,727,314.95     BINE
# 41     -267,810.17     BINE
# 42    9,014,213.86     BINE
# 43      692,254.88     BINE
# 44    7,945,357.41     BINE
# 45    3,590,605.40     BINE
# 46            3.18     BINE
# 47    6,271,568.26     BINE
# 48    3,182,210.48     BINE
# 49      -55,658.72     BINE
# 50     -145,123.07     BINE
# 51      -49,956.58     BINE
# 52      -76,387.45     BINE
# 53      -39,330.33     BINE
# 54       -9,671.36     BINE
# 55     -173,392.50     BINE
# 56      -48,366.94     BINE
# 57      -85,501.41     BINE
# 58      -49,188.06     BINE
# 59      -17,477.23     BINE
# 60      -71,186.77     BINE
# 61      -72,911.63     BINE
# 62      -17,460.08     BINE
# 63      -28,077.43     BINE
# 64     -126,978.53     BINE
# 65     -121,583.49     BINE
# 66      -36,202.56     BINE
# 67      -85,846.42     BINE
# 68       -8,843.33     BINE
# 69      -55,436.41     BINE
# 70     -137,849.85     BINE
# 71      -48,310.35     BINE
# 72      -69,449.20     BINE
# 73           -1.82     BINE
# 74      -79,553.85     BINE
# 75      -56,747.81     BINE
# 76       13,436.20     BINE
# 77   16,003,764.73     BINE
# 78     -358,349.38     BINE
# 79   11,119,351.69     BINE
# 80        6,818.06     BINE
# 81      757,916.72     BINE
# 82            0.00     CASH
# 83            0.00     CASH
# 84            0.00     CASH
# 85            0.00     CASH
# 86          139.56     BTFX
# 87           26.73     BTFX
# 88            0.07     BTFX
# 89            0.03     BTFX
# 90            0.00     BTFX
# 91           23.57     BTSE
# 92        1,009.47     BTSE
# 93          982.95     BTSE
# 94          919.05     BTSE
# 95          269.75     BTSE
# 96      114,736.84     BTSE
# 97       40,971.46     BTSE
# 98   36,352,788.41     BULL
# 99   42,540,511.73     BULL
# 100   4,394,451.53     BULL
# 101     557,704.68     BULL
# 102     619,736.28     BULL
# 103   3,108,660.64     BULL
# 104  12,705,478.65     BULL
# 105  16,812,470.56     BULL
# 106   1,248,835.58     BULL
# 107   1,367,919.47     BULL
# 108           0.50     BULL
# 109           0.17     DEFI
# 110           6.36     DEFI
# 111           0.10     DEFI
# 112       4,906.08     DEFI
# 113      13,972.04     DEFI
# 114           0.00     DEFI
# 115           0.00     DEFI
# 116           0.00     DEFI
# 117           0.00     DEFI
# 118           0.00     DEFI
# 119       8,027.52     DEFI
# 120         114.65     DEFI
# 121           0.00     DEFI
# 122      22,566.35     DEFI
# 123           0.00     DEFI
# 124           0.00     DEFI
# 125           0.00     DEFI
# 126           0.00     DEFI
# 127           0.00     DEFI
# 128           0.00     DEFI
# 129           0.00     DEFI
# 130           0.00     DEFI
# 131           0.00     DEFI
# 132           0.00     DEFI
# 133           0.00     DEFI
# 134           0.00     DEFI
# 135           0.00     DEFI
# 136           0.00     DEFI
# 137           0.00     DEFI
# 138           0.00     DEFI
# 139           0.00     DEFI
# 140           0.00     DEFI
# 141           0.00     DEFI
# 142           0.00     DEFI
# 143      59,999.25     DEFI
# 144       2,370.78     DEFI
# 145     171,738.39     DEFI
# 146       2,880.41     DEFI
# 147       2,978.92     DEFI
# 148         500.17     DEFI
# 149     156,907.29     DEFI
# 150         744.06     DEFI
# 151     296,003.94     DEFI
# 152         538.74     DEFI
# 153     186,679.98     DEFI
# 154     149,751.25     DEFI
# 155       3,139.19     DEFI
# 156         132.03     DEFI
# 157           0.00     DEFI
# 158           0.00     DEFI
# 159           0.00     DEFI
# 160       3,082.20     DEFI
# 161       1,074.58     DEFI
# 162       6,885.98     DEFI
# 163     662,750.80     DEFI
# 164     670,123.34     DEFI
# 165       1,608.30     DEFI
# 166       1,813.91     DEFI
# 167  12,008,833.35     DEFI
# 168  -9,992,297.29     DEFI
# 169      18,086.75     DYDX
# 170  32,067,740.46     ED&F
# 171          83.42      NaN
# 172         180.28      NaN
# 173       1,391.12      NaN
# 174       1,148.60      NaN
# 175       1,206.13      NaN
# 176     572,876.21      NaN
# 177           0.05      NaN
# 178   7,138,852.96      NaN
# 179     105,775.32      NaN
# 180         145.62      NaN
# 181       1,438.27      NaN
# 182         534.04      NaN
# 183         560.40      NaN
# 184     176,456.67      NaN
# 185   2,001,326.30      NaN
# 186   1,280,485.86      NaN
# 187       4,305.91      NaN
# 188     252,979.67      NaN
# 189      13,165.60      NaN
# 190           3.15      NaN
# 191       1,160.53      NaN
# 192       2,647.56      NaN
# 193           0.25      NaN
# 194       5,515.10      NaN
# 195       1,288.09      NaN
# 196         243.80      NaN
# 197       2,326.18      NaN
# 198         400.16      NaN
# 199         191.05      NaN
# 200      60,437.90      NaN
# 201   1,554,315.87      NaN
# 202         904.19      NaN
# 203         609.22      NaN
# 204         121.40      NaN
# 205  11,975,075.34      NaN
# 206  13,312,355.43      NaN
# 207         955.57      NaN
# 208          99.61      NaN
# 209         830.60      NaN
# 210      24,634.05      NaN
# 211           0.00     FUB2
# 212           0.00     FUB2
# 213          21.21     FUB2
# 214           0.00     FUB2
# 215           0.00     FUB2
# 216           0.00     FUB2
# 217           0.00     FUB2
# 218           0.00     FUB2
# 219           0.00     FUB2
# 220           0.00     FUB2
# 221           0.00     FUBI
# 222          78.32     FUBI
# 223           5.06     FUBI
# 224           0.09     FUBI
# 225           4.81     FUBI
# 226           0.04     FUBI
# 227          14.32     FUBI
# 228           1.27     FUBI
# 229           0.38     FUBI
# 230         578.87     FUBI
# 231           0.05     FUBI
# 232           0.19     FUBI
# 233           1.74     GATE
# 234      10,196.03     GATE
# 235         331.47     GATE
# 236           0.00     GATE
# 237           0.00     GATE
# 238           0.00     GATE
# 239          27.17     GATE
# 240           3.48     GATE
# 241           1.33     GATE
# 242          59.40     GATE
# 243      10,046.41     GATE
# 244           0.00     HUB2
# 245           0.00     HUB2
# 246           0.00     HUB2
# 247           0.00     HUB2
# 248           0.00     HUB2
# 249           0.00     HUB2
# 250           0.00     HUB2
# 251           0.00     HUB2
# 252           0.00     HUB2
# 253           0.00     HUB2
# 254           3.26     HUB2
# 255           0.00     HUB2
# 256           6.19     HUBI
# 257           0.00     HUBI
# 258           0.06     HUBI
# 259           0.00     HUBI
# 260      -5,269.93     HUBI
# 261     339,427.71     HUBI
# 262           0.02     HUBI
# 263           2.05     HUBI
# 264         -10.58     HUBI
# 265     197,460.66     HUBI
# 266           0.01     HUBI
# 267           0.20     HUBI
# 268           0.66     HUBI
# 269           0.00     HUBI
# 270           0.00     HUBI
# 271           2.98     HUBI
# 272         194.16     HUBI
# 273      36,699.84     HUBI
# 274           0.10     HUBI
# 275           0.00     HUBI
# 276           0.00     HUBI
# 277           0.02     HUBI
# 278           0.49     HUBI
# 279           0.20     HUBI
# 280           0.00     HUBI
# 281       1,368.13     HUBI
# 282           0.00     HUBI
# 283           6.56     HUBI
# 284           2.72     HUBI
# 285           0.01     HUBI
# 286     570,998.81     HUBI
# 287           0.00     HUBI
# 288         899.66     HUBI
# 289           0.00     HUBI
# 290           0.02     HUBI
# 291           0.00     HUBI
# 292           0.00     HUBI
# 293     197,080.68     HUBI
# 294           0.00     HUBI
# 295       4,790.49     HUBI
# 296     179,279.52     HUBI
# 297   5,442,735.91     HUBI
# 298       3,395.63     HUBI
# 299      11,751.03     HUBI
# 300     115,548.31     HUBI
# 301           3.85     HUBI
# 302      50,092.34     HUBI
# 303           0.85     HUBI
# 304           0.00     HUBI
# 305           0.00     HUBI
# 306           1.07     HUBI
# 307       8,040.32     HUBI
# 308           0.12     HUBI
# 309           0.01     HUBI
# 310           0.19     HUBI
# 311           0.00     HUBI
# 312           0.00     HUBI
# 313           0.00     HUBI
# 314       3,205.95     HUBI
# 315           0.00     HUBI
# 316     618,444.91     HUBI
# 317           0.00     HUBI
# 318           0.14     HUBI
# 319           6.12     HUBI
# 320           0.01     HUBI
# 321       1,279.12     HUBI
# 322           0.00     HUBI
# 323           0.08     HUBI
# 324       3,615.53     HUBI
# 325           0.01     HUBI
# 326           0.00     HUBI
# 327      14,702.41     HUBI
# 328          17.42     HUBI
# 329           2.29     HUBI
# 330       6,073.10     HUBI
# 331           8.42     HUBI
# 332           2.43     HUBI
# 333           0.00     HUBI
# 334          20.00     HUBI
# 335           0.00     HUBI
# 336           0.00     HUBI
# 337           0.34     HUBI
# 338   5,269,183.82     HUBI
# 339           0.47     HUBI
# 340           0.00     HUBI
# 341       2,486.14     HUBI
# 342           0.04     HUBI
# 343         191.52     HUBI
# 344           3.27     HUBI
# 345          16.29     HUBI
# 346           0.01     HUBI
# 347      31,347.50     HUBI
# 348           0.00     HUBI
# 349           0.00     HUBI
# 350           0.00     HUBI
# 351           0.00     HUBI
# 352           0.91     HUBI
# 353           0.00     HUBI
# 354           3.76     KRKE
# 355         190.15     KRKE
# 356         328.82     KRKE
# 357           9.42     KRKE
# 358          11.56     KRKE
# 359         739.48     KRKE
# 360      50,857.55     KRKE
# 361           0.00     KRKE
# 362     127,892.89     KRKE
# 363           0.01     KRKE
# 364           0.00     KRKE
# 365           0.25     KRKE
# 366 -58,445,079.91     BULL
# 367  -4,120,174.94     BULL
# 368  -8,687,803.06     BULL
# 369      18,552.91     GACM
# 370      48,374.36     GACM
# 371       7,142.48     GACM
# 372      38,193.72     GACM
# 373      19,665.17     GACM
# 374     604,674.81     GACM
# 375 -23,378,325.88     GACM
# 376       4,836.69     GACM
# 377      46,637.13     GACM
# 378      24,594.03     GACM
# 379       4,369.31     GACM
# 380      28,409.63     GACM
# 381   1,984,228.25     GACM
# 382 -34,557,433.97     GACM
# 383 -16,096,532.04     GACM
# 384       7,291.16     GACM
# 385       3,637.52     GACM
# 386       5,581.55     GACM
# 387      43,075.92     GACM
# 388      40,443.76     GACM
# 389      18,101.28     GACM
# 390      42,923.21     GACM
# 391       5,771.69     GACM
# 392      56,761.70     GACM
# 393      24,155.17     GACM
# 394      34,724.60     GACM
# 395 -42,800,000.00     GACM
# 396 -89,704,875.74     GACM
# 397  10,001,000.40     GACM
# 398       7,955.39     GACM
# 399       4,162.84     GACM
# 400    -479,744.73     GACM
# 401    -537,297.68     HUBI
# 402    -196,752.26     HUBI
# 403    -151,518.03     HUBI
# 404  -2,186,700.52     HUBI
# 405  -6,148,296.12     HUBI
# 406    -104,612.95     HUBI
# 407    -954,472.73     HUBI
# 408    -187,594.88     OXTF
# 409    -999,987.47     OXTF
# 410         -70.66     XRPF
# 411           0.67     LMAC
# 412           0.00     LMAC
# 413      10,139.55     LMAX
# 414    -176,971.66     OKEX
# 415   9,375,719.01     OKEX
# 416    -315,737.91     OKEX
# 417  12,035,419.29     OKEX
# 418      44,369.66     OKEX
# 419     319,322.55     OKEX
# 420   4,224,041.23     OKEX
# 421       1,775.26     OKEX
# 422      78,708.40     OKEX
# 423        -386.85     OKEX
# 424     -16,131.86     OKEX
# 425          -0.14     OKEX
# 426      -9,965.70     OKEX
# 427     -92,823.45     OKEX
# 428           0.00     OKEX
# 429           0.00     OKEX
# 430           0.00     OKEX
# 431           0.00     OKEX
# 432           0.00     OKEX
# 433           0.00     OKEX
# 434           0.00     OKEX
# 435           0.00     OKEX
# 436           0.00     OKEX
# 437           0.01     OKEX
# 438           0.16     OKEX
# 439           0.01     OKEX
# 440      24,187.06     OKEX
# 441     -18,490.74     OKEX
# 442      14,170.82     OKEX
# 443           0.95     PITX
# 444           0.01     PITX
# 445           0.01     PITX
# 446           0.00     PITX
# 447           0.01     PITX
# 448           0.00     PITX
# 449           0.00     PITX
# 450      99,876.20     SHFT
# 451           0.00     CASH
# 452           0.00     CASH
# 453       4,345.74     CASH
# 454      45,341.17     CASH
# 455     679,657.13     CASH
# 456   1,060,406.64     WOOX
# 457     992,280.98     WOOX
# 458     888,352.55     WOOX
# 459     278,518.91     WOOX

# %% [markdown]
# ## Compare the Ops EOD balance table with the balances reported in the account balance records
